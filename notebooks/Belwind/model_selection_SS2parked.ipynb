# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from owi_data_2_pandas.io import API
import datetime
from pytz import utc
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np
import matplotlib.dates as mdates

# sklearn imports
from sklearn.model_selection import train_test_split

# oma_tracking imports
from oma_tracking.data.preprocessing import sin_cos_angle_inputs

# Import vub Meetenet Vlaamse Banken API functions
from vubmvbc.config import Credentials
from vubmvbc.client import Base
from vubmvbc.objects import Catalog, Data
import vubmvbc.data_getter as dg

from oma_tracking.oma_clustering import ModeClusterer  #pip install hdbscan --no-build-isolation --no-binary :all
from oma_tracking.data.make_dataset import DatasetGetter
from oma_tracking.data.utils import unpack_mode, get_frequencies, get_rated_data, get_parked_data, read_simulations_csv_files

# %%
start  = datetime.datetime(2012,1,1,tzinfo=utc)
stop  = datetime.datetime(2023,7,19,tzinfo=utc)

location = 'bbc01'
name_location = 'BB_C01'

home_folder = "../../"
data_file_name = '_'.join([location, start.strftime("%Y%m%d"), stop.strftime("%Y%m%d")])
data_path = home_folder + "data/bb/raw/" + data_file_name + ".parquet"
data = pd.read_parquet(data_path)


SS1 = get_frequencies(data, 'SS1')
SS2 = get_frequencies(data, 'SS2')
FA1 = get_frequencies(data, 'FA1')

# %%
weather_data_path = "../../data/nw2/mvbc_data_longterm.parquet"
Thorntonbank_data_path = "../../data/nw2/Thorntonbank_data_longterm.parquet"
Westhinder_data_path = "../../data/nw2/Westhinder_data_longterm.parquet"

weather_data = pd.read_parquet(weather_data_path)

scada_inputs = data.filter(regex='mean')

inputs = \
    pd.concat(
        [
            weather_data,
            scada_inputs
        ],
        axis=1
    )

selected_columns = \
    [
       'Sea_water_temperature',
       'Wave_height',
       'Tide_TAW',
       'Average_wave_period',
       'Air_pressure',
       'Air_temperature',
       'mean_'+ name_location + '_rpm',
       'mean_'+ name_location + '_yaw',
       'mean_'+ name_location + '_pitch',
       'mean_'+ name_location + '_power',
       'mean_'+ name_location + '_windspeed',
       'mean_'+ name_location + '_winddirection'
    ]
inputs = inputs[selected_columns]

# %%
### Multiple Linear Regression
# define the 6 operational cases

inputs['operational_case'] = np.nan

cutout_windspeed = 25
windspeed5 = 5
windspeed20 = 20
windspeed2_5 = 2.5
windspeed7_5 = 7.5
windspeed15_5 = 15.5

pitch_1 = -1
pitch19 = 19
pitch19_5 = 19.5
pitch20_5 = 20.5
pitch70 = 70
pitch80 = 80
pitch100 = 100
pitch_20 = -20
pitch1 = 1
pitch70 = 70

rpm2_5 = 2.5
rpm10 = 10
rpm2_05 = 2.05
rpm9_8 = 9.8
rpm10_2 = 10.2
rpm15_9 = 15.9
rpm17 = 17
rpm2_2 = 2.2

power2950 = 2950
power2920 = 2920

# Case 1: parked
inputs['operational_case'] = np.where(
    (inputs.filter(regex='rpm') <= rpm2_5).values[:,0] \
    & (inputs.filter(regex='pitch') >= pitch80).values[:,0] \
    & (inputs.filter(regex='pitch') <= pitch100).values[:,0],
    1,
    inputs['operational_case']
)

# Case 2: pitch:80
inputs['operational_case'] = np.where(
    (inputs.filter(regex='rpm') <= rpm2_5).values[:,0] \
    & (inputs.filter(regex='pitch') >= pitch70).values[:,0] \
    & (inputs.filter(regex='pitch') <= pitch80).values[:,0] \
    & (inputs.filter(regex='windspeed') <= windspeed20).values[:,0],
    2,
    inputs['operational_case']
)

# Case 3: pitch:20
inputs['operational_case'] = np.where(
    (inputs.filter(regex='pitch') >= pitch19_5).values[:,0] \
    & (inputs.filter(regex='pitch') <= pitch20_5).values[:,0] \
    & (inputs.filter(regex='windspeed') <= windspeed5).values[:,0],
    3,
    inputs['operational_case']
)

# Case 4: rpm<10
inputs['operational_case'] = np.where(
    (inputs.filter(regex='rpm') >= rpm2_05).values[:,0] \
    & (inputs.filter(regex='rpm') <= rpm10).values[:,0] \
    & (inputs.filter(regex='pitch') >= pitch_1).values[:,0] \
    & (inputs.filter(regex='pitch') <= pitch19).values[:,0],
    4,
    inputs['operational_case']
)

# Case 5: rpm:10
inputs['operational_case'] = np.where(
    (inputs.filter(regex='rpm') >= rpm9_8).values[:,0] \
    & (inputs.filter(regex='rpm') <= rpm10_2).values[:,0] \
    & (inputs.filter(regex='windspeed') >= windspeed2_5).values[:,0] \
    & (inputs.filter(regex='windspeed') <= windspeed7_5).values[:,0],
    5,
    inputs['operational_case']
)

# Case 6: rpm<16
inputs['operational_case'] = np.where(
    (inputs.filter(regex='rpm') >= rpm10_2).values[:,0] \
    & (inputs.filter(regex='rpm') <= rpm15_9).values[:,0] \
    & (inputs.filter(regex='pitch') > pitch_20).values[:,0] \
    & (inputs.filter(regex='pitch') < pitch1).values[:,0],
    6,
    inputs['operational_case']
)

# Case 7: Rated RPM
inputs['operational_case'] = np.where(
    (inputs.filter(regex='rpm') >= rpm15_9).values[:,0] \
    & (inputs.filter(regex='rpm') <= rpm17).values[:,0] \
    & (inputs.filter(regex='windspeed') <= windspeed15_5).values[:,0] \
    & (inputs.filter(regex='power') <= power2950).values[:,0],
    7,
    inputs['operational_case']
)

# Case 8: Rated Power
inputs['operational_case'] = np.where(
    (inputs.filter(regex='rpm') >= rpm15_9).values[:,0] \
    & (inputs.filter(regex='rpm') <= rpm17).values[:,0] \
    & (inputs.filter(regex='power') >= power2920).values[:,0],
    8,
    inputs['operational_case']
)

# Case 9: Cutout
inputs['operational_case'] = np.where(
    (inputs.filter(regex='pitch') > pitch70).values[:,0] \
    & (inputs.filter(regex='pitch') < pitch80).values[:,0] \
    & (inputs.filter(regex='windspeed') > windspeed20).values[:,0] \
    & (inputs.filter(regex='rpm') <= rpm2_2).values[:,0],
    9,
    inputs['operational_case']
)

import matplotlib

plt.rcParams.update({'font.size': 20})

fig, ax = plt.subplots(figsize=(10, 5))
cmap = matplotlib.colors.ListedColormap(plt.cm.tab10.colors[:len(inputs['operational_case'].unique())-1])
plt.scatter(inputs.filter(regex='windspeed').values[:,0], inputs.filter(regex='rpm').values[:,0], alpha=0.05, c=inputs['operational_case'], cmap=cmap)
# Add the colorbar with alpha = 1
cbar = plt.colorbar()
cbar.ax.set_ylabel('Operational Case')
cbar.set_alpha(1)
cbar.draw_all()
tick_locs = np.linspace(int(inputs['operational_case'].min()), int(inputs['operational_case'].max()), int(2 * len(inputs['operational_case'].unique()) -1 ))[1::2]
cbar_tick_label = np.arange(int(inputs['operational_case'].min()), int(inputs['operational_case'].max() + 1))
cbar.set_ticks(tick_locs)
cbar.set_ticklabels(cbar_tick_label)

# Increase the width of the spines
ax.spines['left'].set_linewidth(2.5)
ax.spines['bottom'].set_linewidth(2.5)
ax.spines['right'].set_linewidth(2.5)
ax.spines['top'].set_linewidth(2.5)

plt.grid(True, color='k', linestyle='--', linewidth=0.5)

plt.xlabel('Wind Speed (m/s)')
plt.ylabel('Rotor Speed (rpm)')
plt.show()
# Out:
# C:\Users\Max\AppData\Local\Temp\ipykernel_4328\1052292621.py:134: MatplotlibDeprecationWarning: The draw_all function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use fig.draw_without_rendering() instead.
#   cbar.draw_all()

# %%
parked_data = get_parked_data(data)
parked_SS2 = get_frequencies(parked_data, 'SS2')
days = parked_SS2.groupby(parked_SS2.index.date).count()[parked_SS2.groupby(parked_SS2.index.date).count() > 144*0.2].dropna().index
parked_SS2['date'] = parked_SS2.index.date
parked_SS2_longterm = parked_SS2[np.isin(parked_SS2['date'], days)].drop(columns=['date'])

# %%
from sklearn.cluster import DBSCAN

time_difference = (parked_SS2_longterm.index-parked_SS2_longterm.index[0]).total_seconds()/60
parked_SS2_longterm['time_difference'] = time_difference
clustering = DBSCAN(eps=60*24*14, min_samples=2).fit(parked_SS2_longterm['time_difference'].values.reshape(-1, 1) )
parked_SS2_longterm['cluster'] = clustering.labels_

# %%
big_clusters = parked_SS2_longterm.groupby('cluster').count()[parked_SS2_longterm.groupby('cluster').count()>144].dropna().index
parked_SS2_longterm_big_clusters = parked_SS2_longterm[np.isin(parked_SS2_longterm['cluster'], big_clusters)]
unique_vals = parked_SS2_longterm_big_clusters['cluster'].unique()
parked_SS2_longterm_big_clusters['cluster'].replace(to_replace=unique_vals,
           value= list(range(len(unique_vals))), inplace=True)
# Out:
# C:\Users\Max\AppData\Local\Temp\ipykernel_4328\1882412710.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parked_SS2_longterm_big_clusters['cluster'].replace(to_replace=unique_vals,

# %%
# sklearn imports
from sklearn.model_selection import train_test_split

# oma_tracking imports
from oma_tracking.data.preprocessing import sin_cos_angle_inputs

random_state = 24
test_size = 0.2
angle_transformed_inputs = sin_cos_angle_inputs(inputs)
angle_columns = [angle for angle in inputs.columns if ('yaw' in angle or 'winddirection' in angle)]
angle_removed_inputs = inputs.drop(columns=angle_columns)

prediction_param = parked_SS2_longterm_big_clusters.copy()
y = prediction_param.dropna()
X = angle_transformed_inputs.loc[y.index].dropna()
y = y.loc[X.index]
X_train, X_test, y_train, y_test = \
train_test_split(X, y, test_size=test_size, random_state=random_state)

from sklearn.preprocessing import StandardScaler
def data_preprocessing(X_train, X_test):
    "Apply standard scaling to the data"
    scaler = StandardScaler()
    X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns, index=X_train.index)
    X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns, index=X_test.index)
    return X_train, X_test
    
X_tr_prep, X_test_prep = data_preprocessing(X_train, X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
mode = 'SS1'
df = inputs.copy().loc[X.index].dropna()
random_state = 24
test_size = 0.2

prediction_param = parked_SS2_longterm_big_clusters.copy()['mean_frequency']



# Train Linear Regression Models for Each Case

linear_regression_models = {}
predictions = {}
r2 = {}
mean_squared_errors = {}
y = prediction_param.dropna()
common_indices = df.index.intersection(y.index)
df_case = df.loc[common_indices]
y_test_cases = {}
predictions_full = {}

operational_cases = df['operational_case'].unique()

for case in operational_cases:
    print(case)
    
    # Filter the dataset for the current operational case
    case_data = df_case[df_case['operational_case'] == case]
    
    # Split the data into input features (X) and target variable (y)
    y = prediction_param.dropna()
    X = case_data.drop(['operational_case'], axis=1).dropna()
    y = y.loc[X.index]
    print(X.shape, y.shape)
    
    X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=test_size, random_state=random_state)
    y_test_cases[case] = y_test
    # Train a linear regression model for the current case
    linear_regression = LinearRegression()
    linear_regression.fit(X_train, y_train)
    
    # Store the trained linear regression model for the current case
    linear_regression_models[case] = linear_regression
    linear_regression_models[case].predict(X_test)
    predictions[case] = pd.Series(linear_regression_models[case].predict(X_test), index=y_test.index)
    predictions_full[case] = pd.Series(linear_regression_models[case].predict(X), index=y.index)

    r2[case] = r2_score(y_test, predictions[case])
    mean_squared_errors[case] = mean_squared_error(y_test, predictions[case])
    print('R2: ', r2[case], 'MSE: ', mean_squared_errors[case])
    plt.scatter(y_test, predictions[case], alpha=0.2, s=1)
plt.plot(np.arange(y.values.min(),y.values.max(),0.001), np.arange(y.values.min(),y.values.max(),0.001), c='k', linestyle='--', linewidth=1)
# Calculate the overall R2 and MSE for the linear regression model through weighted averaging
r2_overall = 0
mse_overall = 0
predictions_ts = pd.Series()
y_test_ts = pd.Series()
predictions_full_ts = pd.Series()
for case in operational_cases:
    r2_overall += r2[case] * len(df_case[df_case['operational_case'] == case])
    mse_overall += mean_squared_errors[case] * len(df_case[df_case['operational_case'] == case])
    predictions_ts = pd.concat([predictions_ts, predictions[case]])
    y_test_ts = pd.concat([y_test_ts, y_test_cases[case]])
    predictions_full_ts = pd.concat([predictions_full_ts, predictions_full[case]])
y_test_ts = y_test_ts
r2_overall /= len(df_case)
mse_overall /= len(df_case)

print('Overall R2: ', r2_overall)
print('Overall MSE: ',mse_overall)


y = prediction_param.dropna()
X = inputs.copy().drop(['operational_case'], axis=1).loc[y.index].dropna()
y = y.loc[X.index]

predictions_ts.sort_index(inplace=True)
predictions_full_ts.sort_index(inplace=True)
y_test_ts.sort_index(inplace=True)
print(len(y.values), len(predictions_ts.values))
test_ts = pd.DataFrame({'y_test': y_test_ts.values, 'predictions': predictions_ts.values}).dropna()
#test_full_ts = pd.DataFrame({'y': y.values[:,0], 'predictions': predictions_full_ts.values}).dropna()
print('R2: ', r2_score(test_ts['y_test'], test_ts['predictions']))
#print('R2: ', r2_score(test_full_ts['y'], test_full_ts['predictions']))
# Out:
# 2.0
# (5253, 12) (5253,)
# R2:  0.5547244044134154 MSE:  0.0003489057679095431
# 1.0
# (8607, 12) (8607,)
# R2:  0.5533189014061088 MSE:  0.0002861312088777817
# 9.0
# (205, 12) (205,)
# R2:  0.4647965164285415 MSE:  0.00012253823441013589
# Overall R2:  0.5525535987667188
# Overall MSE:  0.0003071918700102364
# C:\Users\Max\AppData\Local\Temp\ipykernel_4328\1558054514.py:60: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   predictions_ts = pd.Series()
# C:\Users\Max\AppData\Local\Temp\ipykernel_4328\1558054514.py:61: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   y_test_ts = pd.Series()
# C:\Users\Max\AppData\Local\Temp\ipykernel_4328\1558054514.py:62: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   predictions_full_ts = pd.Series()
# 14068 2814
# R2:  0.593727941405557

# %%
y_test_mask = y.isin(y_test_ts)
y_tr_mask = ~y_test_mask
y_tr_ts = y[y_tr_mask].dropna()
X_tr_ts = X.loc[y_tr_ts.index]
X_test_ts = X.loc[y_test_ts.index]

X_tr_ts_prep, X_test_ts_prep = data_preprocessing(X_tr_ts, X_test_ts)
y_tr_ts_prep, y_test_ts_prep = y_tr_ts.loc[X_tr_ts_prep.index], y_test_ts.loc[X_test_ts_prep.index]

# %%
lin_regr = LinearRegression()
lin_regr.fit(X_tr_ts_prep, y_tr_ts_prep)
# Out:
# LinearRegression()

# %%
color_column = 'operational_case'

lin_regr = LinearRegression()
lin_regr.fit(X_tr_ts_prep, y_tr_ts_prep)

lin_regr_pred = lin_regr.predict(X_test_ts_prep)

mse = mean_squared_error(y_test_ts_prep, lin_regr_pred)
r2 = r2_score(y_test_ts_prep, lin_regr_pred)
print('MSE: ', mse, 'R2: ', r2)

plt.plot(np.arange(y.values.min(),y.values.max(),0.001), np.arange(y.values.min(),y.values.max(),0.001), c='k', linestyle='--', linewidth=1)
plt.scatter(
    y_test_ts_prep, lin_regr_pred, alpha=1, s=1, c=inputs[color_column].loc[y_test_ts_prep.index], cmap=cmap,
    )
plt.colorbar(label=color_column)
plt.xlabel('True Frequency')
plt.ylabel('Predicted Frequency')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# MSE:  0.00035155224492163266 R2:  0.5350619623249282

# %%
import xgboost as xgb
prediction_param = parked_SS2_longterm_big_clusters.copy()['mean_frequency']
y = prediction_param.dropna()
X = angle_transformed_inputs.loc[y.index].dropna()
y = y.loc[X.index]
X_train, X_test, y_train, y_test = \
train_test_split(X, y, test_size=test_size, random_state=random_state)

xgb_regr = xgb.XGBRegressor()
xgb_regr.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
import matplotlib

color_column = 'operational_case'
cmap = matplotlib.colors.ListedColormap(plt.cm.tab10.colors[:len(inputs['operational_case'].unique())-1])

xgb_regressor_pred = xgb_regr.predict(X_test)

mse = mean_squared_error(y_test, xgb_regressor_pred)
r2 = r2_score(y_test, xgb_regressor_pred)
print('MSE: ', mse, 'R2: ', r2)

plt.plot(np.arange(y.values.min(),y.values.max(),0.001), np.arange(y.values.min(),y.values.max(),0.001), c='k', linestyle='--', linewidth=1)
plt.scatter(
    y_test, xgb_regressor_pred, alpha=1, s=1, c=X_test[color_column], cmap=cmap,
    )
plt.colorbar(label=color_column)
plt.xlabel('True Frequency')
plt.ylabel('Predicted Frequency')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# MSE:  8.873391697986684e-05 R2:  0.8805780593594064

# %%
# Catboost
import catboost as cb
cb_reg_1 = cb.CatBoostRegressor(task_type='GPU', verbose=200)
cb_reg_1.fit(X_train, y_train)
# Out:
# Learning rate set to 0.055466
# 0:	learn: 0.0262129	total: 740ms	remaining: 12m 19s
# 200:	learn: 0.0088381	total: 1m 30s	remaining: 5m 58s
# 400:	learn: 0.0083536	total: 3m 2s	remaining: 4m 32s
# 600:	learn: 0.0081874	total: 4m 47s	remaining: 3m 10s
# 800:	learn: 0.0080876	total: 6m 54s	remaining: 1m 42s
# 999:	learn: 0.0079921	total: 8m 35s	remaining: 0us

# %%
cb_preds = cb_reg_1.predict(X_test)
cb_mse = mean_squared_error(y_test, cb_preds)
cb_r2 = r2_score(y_test, cb_preds)
print("CB MSE:", cb_mse, "CB R2:", cb_r2)

plt.plot(np.arange(y.values.min(),y.values.max(),0.001), np.arange(y.values.min(),y.values.max(),0.001), c='k', linestyle='--', linewidth=1)
plt.scatter(
    y_test, cb_preds, alpha=0.1, s=1, c=X_test[color_column], cmap=cmap,
    )
plt.colorbar(label=color_column)
plt.xlabel('True Frequency')
plt.ylabel('Predicted Frequency')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# CB MSE: 8.237879161436013e-05 CB R2: 0.8891310617512119

# %%
from scipy.stats import norm
residual = y_test.values  - cb_preds
print(np.mean(residual))
print(np.std(residual))
plt.hist(residual, bins=100, density=True)
x_axis = np.arange(-0.01, 0.01, 1e-7)
plt.plot(x_axis, norm.pdf(x_axis, np.mean(residual), np.std(residual)))
plt.grid(True, color='k', linestyle='--', linewidth=0.5)
plt.show()
# Out:
# -0.00018546366072696532
# 0.009074381237578123

# %%
from sklearn.ensemble import RandomForestRegressor

rf_regr = RandomForestRegressor()
rf_regr.fit(X_tr_ts, y_tr_ts)
# Out:
# RandomForestRegressor()

# %%
rf_predictions = rf_regr.predict(X_test_ts)
rf_mse = mean_squared_error(y_test_ts, rf_predictions)
rf_r2 = r2_score(y_test_ts, rf_predictions)
print("rf MSE:", rf_mse, "rf R2:", rf_r2)

plt.plot(np.arange(y.values.min(),y.values.max(),0.001), np.arange(y.values.min(),y.values.max(),0.001), c='k', linestyle='--', linewidth=1)
plt.scatter(
    y_test_ts, rf_predictions, alpha=0.1, s=1, c=inputs[color_column].loc[y_test_ts.index], cmap=cmap,
    )
plt.colorbar(label=color_column)
plt.xlabel('True Frequency')
plt.ylabel('Predicted Frequency')
plt.show()
# Out:
# rf MSE: 9.126748457199892e-05 rf R2: 0.8792961052207068

# %%
from tensorflow import keras
from keras import layers

keras_nn = keras.Sequential()
keras_nn.add(layers.Flatten())
keras_nn.add(
        layers.Dense(
            # Define the hyperparameter.
            units=32,
            activation="relu",
        )
    )
keras_nn.add(layers.Dense(1, activation="linear"))
keras_nn.compile(
        optimizer="adam", loss="mean_squared_error", metrics=["mean_squared_error"],
    )

# %%
keras_nn.fit(X_tr_ts_prep, y_tr_ts_prep, epochs=100, batch_size=32, verbose=1)
# Out:
# Epoch 1/100
# 352/352 [==============================] - 2s 2ms/step - loss: 0.4092 - mean_squared_error: 0.4092
# Epoch 2/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0387 - mean_squared_error: 0.0387
# Epoch 3/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0206 - mean_squared_error: 0.0206
# Epoch 4/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 5/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0083 - mean_squared_error: 0.0083
# Epoch 6/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 7/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 8/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 9/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 10/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0025 - mean_squared_error: 0.0025
# Epoch 11/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 12/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 13/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 14/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0015 - mean_squared_error: 0.0015
# Epoch 15/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 16/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0013 - mean_squared_error: 0.0013
# Epoch 17/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 18/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 19/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 20/100
# 352/352 [==============================] - 1s 2ms/step - loss: 8.8221e-04 - mean_squared_error: 8.8221e-04
# Epoch 21/100
# 352/352 [==============================] - 1s 2ms/step - loss: 8.6935e-04 - mean_squared_error: 8.6935e-04
# Epoch 22/100
# 352/352 [==============================] - 1s 2ms/step - loss: 8.2406e-04 - mean_squared_error: 8.2406e-04
# Epoch 23/100
# 352/352 [==============================] - 1s 2ms/step - loss: 6.8673e-04 - mean_squared_error: 6.8673e-04
# Epoch 24/100
# 352/352 [==============================] - 1s 2ms/step - loss: 8.8230e-04 - mean_squared_error: 8.8230e-04
# Epoch 25/100
# 352/352 [==============================] - 1s 2ms/step - loss: 7.9048e-04 - mean_squared_error: 7.9048e-04
# Epoch 26/100
# 352/352 [==============================] - 1s 2ms/step - loss: 6.3136e-04 - mean_squared_error: 6.3136e-04
# Epoch 27/100
# 352/352 [==============================] - 1s 2ms/step - loss: 6.3517e-04 - mean_squared_error: 6.3517e-04
# Epoch 28/100
# 352/352 [==============================] - 1s 2ms/step - loss: 4.5652e-04 - mean_squared_error: 4.5652e-04
# Epoch 29/100
# 352/352 [==============================] - 1s 2ms/step - loss: 4.7551e-04 - mean_squared_error: 4.7551e-04
# Epoch 30/100
# 352/352 [==============================] - 1s 2ms/step - loss: 6.4512e-04 - mean_squared_error: 6.4512e-04
# Epoch 31/100
# 352/352 [==============================] - 1s 3ms/step - loss: 4.1895e-04 - mean_squared_error: 4.1895e-04
# Epoch 32/100
# 352/352 [==============================] - 1s 2ms/step - loss: 3.7012e-04 - mean_squared_error: 3.7012e-04
# Epoch 33/100
# 352/352 [==============================] - 1s 2ms/step - loss: 3.5268e-04 - mean_squared_error: 3.5268e-04
# Epoch 34/100
# 352/352 [==============================] - 1s 3ms/step - loss: 3.4362e-04 - mean_squared_error: 3.4362e-04
# Epoch 35/100
# 352/352 [==============================] - 1s 2ms/step - loss: 3.1573e-04 - mean_squared_error: 3.1573e-04
# Epoch 36/100
# 352/352 [==============================] - 1s 2ms/step - loss: 3.1158e-04 - mean_squared_error: 3.1158e-04
# Epoch 37/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.9695e-04 - mean_squared_error: 2.9695e-04
# Epoch 38/100
# 352/352 [==============================] - 1s 2ms/step - loss: 5.2388e-04 - mean_squared_error: 5.2388e-04
# Epoch 39/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.6366e-04 - mean_squared_error: 2.6366e-04
# Epoch 40/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.7681e-04 - mean_squared_error: 2.7681e-04
# Epoch 41/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.6935e-04 - mean_squared_error: 2.6935e-04
# Epoch 42/100
# 352/352 [==============================] - 1s 2ms/step - loss: 4.5758e-04 - mean_squared_error: 4.5758e-04
# Epoch 43/100
# 352/352 [==============================] - 1s 3ms/step - loss: 4.2290e-04 - mean_squared_error: 4.2290e-04
# Epoch 44/100
# 352/352 [==============================] - 1s 3ms/step - loss: 2.0992e-04 - mean_squared_error: 2.0992e-04
# Epoch 45/100
# 352/352 [==============================] - 1s 3ms/step - loss: 2.0180e-04 - mean_squared_error: 2.0180e-04
# Epoch 46/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.9307e-04 - mean_squared_error: 1.9307e-04
# Epoch 47/100
# 352/352 [==============================] - 1s 2ms/step - loss: 3.9127e-04 - mean_squared_error: 3.9127e-04
# Epoch 48/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.0603e-04 - mean_squared_error: 2.0603e-04
# Epoch 49/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.0953e-04 - mean_squared_error: 2.0953e-04
# Epoch 50/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.3522e-04 - mean_squared_error: 2.3522e-04
# Epoch 51/100
# 352/352 [==============================] - 1s 2ms/step - loss: 3.8939e-04 - mean_squared_error: 3.8939e-04
# Epoch 52/100
# 352/352 [==============================] - 1s 2ms/step - loss: 3.0797e-04 - mean_squared_error: 3.0797e-04
# Epoch 53/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.6751e-04 - mean_squared_error: 1.6751e-04
# Epoch 54/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.0953e-04 - mean_squared_error: 2.0953e-04
# Epoch 55/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.8976e-04 - mean_squared_error: 1.8976e-04
# Epoch 56/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.9578e-04 - mean_squared_error: 1.9578e-04
# Epoch 57/100
# 352/352 [==============================] - 1s 2ms/step - loss: 3.3775e-04 - mean_squared_error: 3.3775e-04
# Epoch 58/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.4524e-04 - mean_squared_error: 2.4524e-04
# Epoch 59/100
# 352/352 [==============================] - 1s 2ms/step - loss: 3.4218e-04 - mean_squared_error: 3.4218e-04
# Epoch 60/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.6147e-04 - mean_squared_error: 1.6147e-04
# Epoch 61/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.5667e-04 - mean_squared_error: 1.5667e-04
# Epoch 62/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.7368e-04 - mean_squared_error: 1.7368e-04
# Epoch 63/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.5154e-04 - mean_squared_error: 1.5154e-04
# Epoch 64/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.6794e-04 - mean_squared_error: 1.6794e-04
# Epoch 65/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.8087e-04 - mean_squared_error: 2.8087e-04
# Epoch 66/100
# 352/352 [==============================] - 1s 2ms/step - loss: 3.0952e-04 - mean_squared_error: 3.0952e-04
# Epoch 67/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.4229e-04 - mean_squared_error: 2.4229e-04
# Epoch 68/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.7697e-04 - mean_squared_error: 1.7697e-04
# Epoch 69/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.5360e-04 - mean_squared_error: 1.5360e-04
# Epoch 70/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.4140e-04 - mean_squared_error: 1.4140e-04
# Epoch 71/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.8501e-04 - mean_squared_error: 1.8501e-04
# Epoch 72/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.9328e-04 - mean_squared_error: 2.9328e-04
# Epoch 73/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.9799e-04 - mean_squared_error: 1.9799e-04
# Epoch 74/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.5810e-04 - mean_squared_error: 1.5810e-04
# Epoch 75/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.4453e-04 - mean_squared_error: 1.4453e-04
# Epoch 76/100
# 352/352 [==============================] - 1s 3ms/step - loss: 2.0385e-04 - mean_squared_error: 2.0385e-04
# Epoch 77/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.9751e-04 - mean_squared_error: 2.9751e-04
# Epoch 78/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.5220e-04 - mean_squared_error: 1.5220e-04
# Epoch 79/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.4039e-04 - mean_squared_error: 1.4039e-04
# Epoch 80/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.1901e-04 - mean_squared_error: 2.1901e-04
# Epoch 81/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.3450e-04 - mean_squared_error: 1.3450e-04
# Epoch 82/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.3175e-04 - mean_squared_error: 1.3175e-04
# Epoch 83/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.7821e-04 - mean_squared_error: 1.7821e-04
# Epoch 84/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.1259e-04 - mean_squared_error: 2.1259e-04
# Epoch 85/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.5203e-04 - mean_squared_error: 1.5203e-04
# Epoch 86/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.8207e-04 - mean_squared_error: 1.8207e-04
# Epoch 87/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.4630e-04 - mean_squared_error: 1.4630e-04
# Epoch 88/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.3936e-04 - mean_squared_error: 1.3936e-04
# Epoch 89/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.8349e-04 - mean_squared_error: 1.8349e-04
# Epoch 90/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.9221e-04 - mean_squared_error: 1.9221e-04
# Epoch 91/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.3640e-04 - mean_squared_error: 1.3640e-04
# Epoch 92/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.7774e-04 - mean_squared_error: 1.7774e-04
# Epoch 93/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.8276e-04 - mean_squared_error: 1.8276e-04
# Epoch 94/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.3849e-04 - mean_squared_error: 1.3849e-04
# Epoch 95/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.7117e-04 - mean_squared_error: 1.7117e-04
# Epoch 96/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.4422e-04 - mean_squared_error: 1.4422e-04
# Epoch 97/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.3477e-04 - mean_squared_error: 1.3477e-04
# Epoch 98/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.4172e-04 - mean_squared_error: 1.4172e-04
# Epoch 99/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.8354e-04 - mean_squared_error: 1.8354e-04
# Epoch 100/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.8779e-04 - mean_squared_error: 1.8779e-04

# %%
nn_predictions = keras_nn.predict(X_test_ts_prep)
nn_mse = mean_squared_error(y_test_ts_prep, nn_predictions)
nn_r2 = r2_score(y_test_ts_prep, nn_predictions)
print("NN MSE:", nn_mse, "NN R2:", nn_r2)

plt.plot(np.arange(y.values.min(),y.values.max(),0.001), np.arange(y.values.min(),y.values.max(),0.001), c='k', linestyle='--', linewidth=1)
plt.scatter(
    y_test_ts_prep, nn_predictions, alpha=0.1, s=1,c=inputs[color_column].loc[y_test_ts_prep.index], cmap=cmap,
    )
plt.colorbar(label=color_column)
plt.xlabel('True Frequency')
plt.ylabel('Predicted Frequency')
plt.show()
# Out:
# NN MSE: 0.0001431880423926568 NN R2: 0.8106296619911578

# %%
from tensorflow import keras
from keras import layers

keras_nn2 = keras.Sequential()
keras_nn2.add(layers.Flatten())
keras_nn2.add(
        layers.Dense(
            # Define the hyperparameter.
            units=32,
            activation="relu",
        )
    )
keras_nn2.add(
        layers.Dense(
            # Define the hyperparameter.
            units=32,
            activation="relu",
        )
    )
keras_nn2.add(layers.Dense(1, activation="linear"))
keras_nn2.compile(
        optimizer="adam", loss="mean_squared_error", metrics=["mean_squared_error"],
    )
keras_nn2.fit(X_tr_ts_prep, y_tr_ts_prep, epochs=100, batch_size=32, verbose=1)
# Out:
# Epoch 1/100
# 352/352 [==============================] - 2s 2ms/step - loss: 0.1533 - mean_squared_error: 0.1533
# Epoch 2/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0143 - mean_squared_error: 0.0143
# Epoch 3/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0065 - mean_squared_error: 0.0065
# Epoch 4/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 5/100
# 352/352 [==============================] - 1s 3ms/step - loss: 0.0031 - mean_squared_error: 0.0031
# Epoch 6/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0024 - mean_squared_error: 0.0024
# Epoch 7/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 8/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0017 - mean_squared_error: 0.0017
# Epoch 9/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 10/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0012 - mean_squared_error: 0.0012
# Epoch 11/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 12/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0016 - mean_squared_error: 0.0016
# Epoch 13/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 14/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0010 - mean_squared_error: 0.0010
# Epoch 15/100
# 352/352 [==============================] - 1s 2ms/step - loss: 7.5612e-04 - mean_squared_error: 7.5612e-04
# Epoch 16/100
# 352/352 [==============================] - 1s 2ms/step - loss: 6.3487e-04 - mean_squared_error: 6.3487e-04
# Epoch 17/100
# 352/352 [==============================] - 1s 2ms/step - loss: 7.9975e-04 - mean_squared_error: 7.9975e-04
# Epoch 18/100
# 352/352 [==============================] - 1s 2ms/step - loss: 9.1018e-04 - mean_squared_error: 9.1018e-04
# Epoch 19/100
# 352/352 [==============================] - 1s 2ms/step - loss: 9.6111e-04 - mean_squared_error: 9.6111e-04
# Epoch 20/100
# 352/352 [==============================] - 1s 2ms/step - loss: 5.5575e-04 - mean_squared_error: 5.5575e-04
# Epoch 21/100
# 352/352 [==============================] - 1s 2ms/step - loss: 3.7619e-04 - mean_squared_error: 3.7619e-04
# Epoch 22/100
# 352/352 [==============================] - 1s 2ms/step - loss: 3.7472e-04 - mean_squared_error: 3.7472e-04
# Epoch 23/100
# 352/352 [==============================] - 1s 2ms/step - loss: 4.9682e-04 - mean_squared_error: 4.9682e-04
# Epoch 24/100
# 352/352 [==============================] - 1s 2ms/step - loss: 6.1088e-04 - mean_squared_error: 6.1088e-04
# Epoch 25/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.6860e-04 - mean_squared_error: 2.6860e-04
# Epoch 26/100
# 352/352 [==============================] - 1s 2ms/step - loss: 3.1894e-04 - mean_squared_error: 3.1894e-04
# Epoch 27/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.8994e-04 - mean_squared_error: 2.8994e-04
# Epoch 28/100
# 352/352 [==============================] - 1s 2ms/step - loss: 4.4603e-04 - mean_squared_error: 4.4603e-04
# Epoch 29/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.3730e-04 - mean_squared_error: 2.3730e-04
# Epoch 30/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.9452e-04 - mean_squared_error: 1.9452e-04
# Epoch 31/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.1169e-04 - mean_squared_error: 2.1169e-04
# Epoch 32/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.1467e-04 - mean_squared_error: 2.1467e-04
# Epoch 33/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.5692e-04 - mean_squared_error: 2.5692e-04
# Epoch 34/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.8863e-04 - mean_squared_error: 2.8863e-04
# Epoch 35/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.4683e-04 - mean_squared_error: 2.4683e-04
# Epoch 36/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.7033e-04 - mean_squared_error: 1.7033e-04
# Epoch 37/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.5746e-04 - mean_squared_error: 1.5746e-04
# Epoch 38/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.5853e-04 - mean_squared_error: 1.5853e-04
# Epoch 39/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.5098e-04 - mean_squared_error: 1.5098e-04
# Epoch 40/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.8033e-04 - mean_squared_error: 1.8033e-04
# Epoch 41/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.3632e-04 - mean_squared_error: 2.3632e-04
# Epoch 42/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.2143e-04 - mean_squared_error: 2.2143e-04
# Epoch 43/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.7294e-04 - mean_squared_error: 1.7294e-04
# Epoch 44/100
# 352/352 [==============================] - 1s 3ms/step - loss: 1.6128e-04 - mean_squared_error: 1.6128e-04
# Epoch 45/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.6596e-04 - mean_squared_error: 1.6596e-04
# Epoch 46/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.4360e-04 - mean_squared_error: 1.4360e-04
# Epoch 47/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2903e-04 - mean_squared_error: 1.2903e-04
# Epoch 48/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.3134e-04 - mean_squared_error: 1.3134e-04
# Epoch 49/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.4471e-04 - mean_squared_error: 1.4471e-04
# Epoch 50/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.4208e-04 - mean_squared_error: 1.4208e-04
# Epoch 51/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.6776e-04 - mean_squared_error: 1.6776e-04
# Epoch 52/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.3358e-04 - mean_squared_error: 1.3358e-04
# Epoch 53/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2753e-04 - mean_squared_error: 1.2753e-04
# Epoch 54/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2589e-04 - mean_squared_error: 1.2589e-04
# Epoch 55/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.3143e-04 - mean_squared_error: 1.3143e-04
# Epoch 56/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2630e-04 - mean_squared_error: 1.2630e-04
# Epoch 57/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2360e-04 - mean_squared_error: 1.2360e-04
# Epoch 58/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.4317e-04 - mean_squared_error: 1.4317e-04
# Epoch 59/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2877e-04 - mean_squared_error: 1.2877e-04
# Epoch 60/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2151e-04 - mean_squared_error: 1.2151e-04
# Epoch 61/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1802e-04 - mean_squared_error: 1.1802e-04
# Epoch 62/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2124e-04 - mean_squared_error: 1.2124e-04
# Epoch 63/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1703e-04 - mean_squared_error: 1.1703e-04
# Epoch 64/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1857e-04 - mean_squared_error: 1.1857e-04
# Epoch 65/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2909e-04 - mean_squared_error: 1.2909e-04
# Epoch 66/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1322e-04 - mean_squared_error: 1.1322e-04
# Epoch 67/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2022e-04 - mean_squared_error: 1.2022e-04
# Epoch 68/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2454e-04 - mean_squared_error: 1.2454e-04
# Epoch 69/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1571e-04 - mean_squared_error: 1.1571e-04
# Epoch 70/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1416e-04 - mean_squared_error: 1.1416e-04
# Epoch 71/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1311e-04 - mean_squared_error: 1.1311e-04
# Epoch 72/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1062e-04 - mean_squared_error: 1.1062e-04
# Epoch 73/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1655e-04 - mean_squared_error: 1.1655e-04
# Epoch 74/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0937e-04 - mean_squared_error: 1.0937e-04
# Epoch 75/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0921e-04 - mean_squared_error: 1.0921e-04
# Epoch 76/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1224e-04 - mean_squared_error: 1.1224e-04
# Epoch 77/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1262e-04 - mean_squared_error: 1.1262e-04
# Epoch 78/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1315e-04 - mean_squared_error: 1.1315e-04
# Epoch 79/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0469e-04 - mean_squared_error: 1.0469e-04
# Epoch 80/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1388e-04 - mean_squared_error: 1.1388e-04
# Epoch 81/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0433e-04 - mean_squared_error: 1.0433e-04
# Epoch 82/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0829e-04 - mean_squared_error: 1.0829e-04
# Epoch 83/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0395e-04 - mean_squared_error: 1.0395e-04
# Epoch 84/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0687e-04 - mean_squared_error: 1.0687e-04
# Epoch 85/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0550e-04 - mean_squared_error: 1.0550e-04
# Epoch 86/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0467e-04 - mean_squared_error: 1.0467e-04
# Epoch 87/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0876e-04 - mean_squared_error: 1.0876e-04
# Epoch 88/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0979e-04 - mean_squared_error: 1.0979e-04
# Epoch 89/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0525e-04 - mean_squared_error: 1.0525e-04
# Epoch 90/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0615e-04 - mean_squared_error: 1.0615e-04
# Epoch 91/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0231e-04 - mean_squared_error: 1.0231e-04
# Epoch 92/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0169e-04 - mean_squared_error: 1.0169e-04
# Epoch 93/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0238e-04 - mean_squared_error: 1.0238e-04
# Epoch 94/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0426e-04 - mean_squared_error: 1.0426e-04
# Epoch 95/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0013e-04 - mean_squared_error: 1.0013e-04
# Epoch 96/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0339e-04 - mean_squared_error: 1.0339e-04
# Epoch 97/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1009e-04 - mean_squared_error: 1.1009e-04
# Epoch 98/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0462e-04 - mean_squared_error: 1.0462e-04
# Epoch 99/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0612e-04 - mean_squared_error: 1.0612e-04
# Epoch 100/100
# 352/352 [==============================] - 1s 2ms/step - loss: 9.9922e-05 - mean_squared_error: 9.9922e-05

# %%
nn2_predictions = keras_nn2.predict(X_test_ts_prep)
nn2_mse = mean_squared_error(y_test_ts_prep, nn2_predictions)
nn2_r2 = r2_score(y_test_ts_prep, nn2_predictions)
print("NN MSE:", nn2_mse, "NN R2:", nn2_r2)

plt.plot(np.arange(y.values.min(),y.values.max(),0.001), np.arange(y.values.min(),y.values.max(),0.001), c='k', linestyle='--', linewidth=1)
plt.scatter(
    y_test_ts_prep, nn2_predictions, alpha=0.1, s=1,c=inputs[color_column].loc[y_test_ts_prep.index], cmap=cmap,
    )
plt.colorbar(label=color_column)
plt.xlabel('True Frequency')
plt.ylabel('Predicted Frequency')
plt.show()
# Out:
# NN MSE: 0.00011478370645413304 NN R2: 0.8481952198946913

# %%
from tensorflow import keras
from keras import layers

keras_nn3 = keras.Sequential()
keras_nn3.add(layers.Flatten())
keras_nn3.add(
        layers.Dense(
            # Define the hyperparameter.
            units=32,
            activation="relu",
        )
    )
keras_nn3.add(
        layers.Dense(
            # Define the hyperparameter.
            units=32,
            activation="relu",
        )
    )
keras_nn3.add(
        layers.Dense(
            # Define the hyperparameter.
            units=32,
            activation="relu",
        )
    )
keras_nn3.add(layers.Dense(1, activation="linear"))
keras_nn3.compile(
        optimizer="adam", loss="mean_squared_error", metrics=["mean_squared_error"],
    )
keras_nn3.fit(X_tr_ts_prep, y_tr_ts_prep, epochs=100, batch_size=32, verbose=1)
# Out:
# Epoch 1/100
# 352/352 [==============================] - 2s 2ms/step - loss: 0.1069 - mean_squared_error: 0.1069
# Epoch 2/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0086 - mean_squared_error: 0.0086
# Epoch 3/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 4/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 5/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 6/100
# 352/352 [==============================] - 1s 2ms/step - loss: 0.0011 - mean_squared_error: 0.0011
# Epoch 7/100
# 352/352 [==============================] - 1s 2ms/step - loss: 8.5856e-04 - mean_squared_error: 8.5856e-04
# Epoch 8/100
# 352/352 [==============================] - 1s 2ms/step - loss: 7.1207e-04 - mean_squared_error: 7.1207e-04
# Epoch 9/100
# 352/352 [==============================] - 1s 2ms/step - loss: 5.7239e-04 - mean_squared_error: 5.7239e-04
# Epoch 10/100
# 352/352 [==============================] - 1s 3ms/step - loss: 5.9910e-04 - mean_squared_error: 5.9910e-04
# Epoch 11/100
# 352/352 [==============================] - 1s 2ms/step - loss: 6.5504e-04 - mean_squared_error: 6.5504e-04
# Epoch 12/100
# 352/352 [==============================] - 1s 2ms/step - loss: 4.9632e-04 - mean_squared_error: 4.9632e-04
# Epoch 13/100
# 352/352 [==============================] - 1s 2ms/step - loss: 3.8184e-04 - mean_squared_error: 3.8184e-04
# Epoch 14/100
# 352/352 [==============================] - 1s 2ms/step - loss: 4.8376e-04 - mean_squared_error: 4.8376e-04
# Epoch 15/100
# 352/352 [==============================] - 1s 2ms/step - loss: 3.2396e-04 - mean_squared_error: 3.2396e-04
# Epoch 16/100
# 352/352 [==============================] - 1s 2ms/step - loss: 3.4747e-04 - mean_squared_error: 3.4747e-04
# Epoch 17/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.5404e-04 - mean_squared_error: 2.5404e-04
# Epoch 18/100
# 352/352 [==============================] - 1s 3ms/step - loss: 3.3638e-04 - mean_squared_error: 3.3638e-04
# Epoch 19/100
# 352/352 [==============================] - 1s 3ms/step - loss: 3.4094e-04 - mean_squared_error: 3.4094e-04
# Epoch 20/100
# 352/352 [==============================] - 1s 3ms/step - loss: 2.4702e-04 - mean_squared_error: 2.4702e-04
# Epoch 21/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.1426e-04 - mean_squared_error: 2.1426e-04
# Epoch 22/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.2456e-04 - mean_squared_error: 2.2456e-04
# Epoch 23/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.9657e-04 - mean_squared_error: 2.9657e-04
# Epoch 24/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.1948e-04 - mean_squared_error: 2.1948e-04
# Epoch 25/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.8084e-04 - mean_squared_error: 1.8084e-04
# Epoch 26/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.7567e-04 - mean_squared_error: 1.7567e-04
# Epoch 27/100
# 352/352 [==============================] - 1s 2ms/step - loss: 2.2074e-04 - mean_squared_error: 2.2074e-04
# Epoch 28/100
# 352/352 [==============================] - 1s 3ms/step - loss: 1.7205e-04 - mean_squared_error: 1.7205e-04
# Epoch 29/100
# 352/352 [==============================] - 1s 3ms/step - loss: 1.5699e-04 - mean_squared_error: 1.5699e-04
# Epoch 30/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.5786e-04 - mean_squared_error: 1.5786e-04
# Epoch 31/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.6095e-04 - mean_squared_error: 1.6095e-04
# Epoch 32/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.4995e-04 - mean_squared_error: 1.4995e-04
# Epoch 33/100
# 352/352 [==============================] - 1s 3ms/step - loss: 1.4450e-04 - mean_squared_error: 1.4450e-04
# Epoch 34/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.4633e-04 - mean_squared_error: 1.4633e-04
# Epoch 35/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.3921e-04 - mean_squared_error: 1.3921e-04
# Epoch 36/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.3780e-04 - mean_squared_error: 1.3780e-04
# Epoch 37/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.6312e-04 - mean_squared_error: 1.6312e-04
# Epoch 38/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.6781e-04 - mean_squared_error: 1.6781e-04
# Epoch 39/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.4948e-04 - mean_squared_error: 1.4948e-04
# Epoch 40/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.3644e-04 - mean_squared_error: 1.3644e-04
# Epoch 41/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.3107e-04 - mean_squared_error: 1.3107e-04
# Epoch 42/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2285e-04 - mean_squared_error: 1.2285e-04
# Epoch 43/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2316e-04 - mean_squared_error: 1.2316e-04
# Epoch 44/100
# 352/352 [==============================] - 1s 3ms/step - loss: 1.2352e-04 - mean_squared_error: 1.2352e-04
# Epoch 45/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2642e-04 - mean_squared_error: 1.2642e-04
# Epoch 46/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1679e-04 - mean_squared_error: 1.1679e-04
# Epoch 47/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2064e-04 - mean_squared_error: 1.2064e-04
# Epoch 48/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1754e-04 - mean_squared_error: 1.1754e-04
# Epoch 49/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2254e-04 - mean_squared_error: 1.2254e-04
# Epoch 50/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2380e-04 - mean_squared_error: 1.2380e-04
# Epoch 51/100
# 352/352 [==============================] - 1s 3ms/step - loss: 1.1615e-04 - mean_squared_error: 1.1615e-04
# Epoch 52/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1006e-04 - mean_squared_error: 1.1006e-04
# Epoch 53/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.2114e-04 - mean_squared_error: 1.2114e-04
# Epoch 54/100
# 352/352 [==============================] - 1s 3ms/step - loss: 1.1053e-04 - mean_squared_error: 1.1053e-04
# Epoch 55/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0950e-04 - mean_squared_error: 1.0950e-04
# Epoch 56/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0948e-04 - mean_squared_error: 1.0948e-04
# Epoch 57/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1724e-04 - mean_squared_error: 1.1724e-04
# Epoch 58/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1738e-04 - mean_squared_error: 1.1738e-04
# Epoch 59/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0606e-04 - mean_squared_error: 1.0606e-04
# Epoch 60/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0964e-04 - mean_squared_error: 1.0964e-04
# Epoch 61/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0946e-04 - mean_squared_error: 1.0946e-04
# Epoch 62/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0660e-04 - mean_squared_error: 1.0660e-04
# Epoch 63/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0587e-04 - mean_squared_error: 1.0587e-04
# Epoch 64/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0289e-04 - mean_squared_error: 1.0289e-04
# Epoch 65/100
# 352/352 [==============================] - 1s 3ms/step - loss: 1.0784e-04 - mean_squared_error: 1.0784e-04
# Epoch 66/100
# 352/352 [==============================] - 1s 3ms/step - loss: 1.4090e-04 - mean_squared_error: 1.4090e-04
# Epoch 67/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0841e-04 - mean_squared_error: 1.0841e-04
# Epoch 68/100
# 352/352 [==============================] - 1s 3ms/step - loss: 1.0282e-04 - mean_squared_error: 1.0282e-04
# Epoch 69/100
# 352/352 [==============================] - 1s 2ms/step - loss: 9.7804e-05 - mean_squared_error: 9.7804e-05
# Epoch 70/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0348e-04 - mean_squared_error: 1.0348e-04
# Epoch 71/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0478e-04 - mean_squared_error: 1.0478e-04
# Epoch 72/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0180e-04 - mean_squared_error: 1.0180e-04
# Epoch 73/100
# 352/352 [==============================] - 1s 2ms/step - loss: 9.8067e-05 - mean_squared_error: 9.8067e-05
# Epoch 74/100
# 352/352 [==============================] - 1s 3ms/step - loss: 9.8491e-05 - mean_squared_error: 9.8491e-05
# Epoch 75/100
# 352/352 [==============================] - 1s 3ms/step - loss: 1.0455e-04 - mean_squared_error: 1.0455e-04
# Epoch 76/100
# 352/352 [==============================] - 1s 3ms/step - loss: 1.0366e-04 - mean_squared_error: 1.0366e-04
# Epoch 77/100
# 352/352 [==============================] - 1s 2ms/step - loss: 9.8975e-05 - mean_squared_error: 9.8975e-05
# Epoch 78/100
# 352/352 [==============================] - 1s 3ms/step - loss: 1.0568e-04 - mean_squared_error: 1.0568e-04
# Epoch 79/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0005e-04 - mean_squared_error: 1.0005e-04
# Epoch 80/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0334e-04 - mean_squared_error: 1.0334e-04
# Epoch 81/100
# 352/352 [==============================] - 1s 2ms/step - loss: 9.7223e-05 - mean_squared_error: 9.7223e-05
# Epoch 82/100
# 352/352 [==============================] - 1s 2ms/step - loss: 9.5715e-05 - mean_squared_error: 9.5715e-05
# Epoch 83/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0518e-04 - mean_squared_error: 1.0518e-04
# Epoch 84/100
# 352/352 [==============================] - 1s 2ms/step - loss: 9.5704e-05 - mean_squared_error: 9.5704e-05
# Epoch 85/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0008e-04 - mean_squared_error: 1.0008e-04
# Epoch 86/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.1046e-04 - mean_squared_error: 1.1046e-04
# Epoch 87/100
# 352/352 [==============================] - 1s 3ms/step - loss: 9.7482e-05 - mean_squared_error: 9.7482e-05
# Epoch 88/100
# 352/352 [==============================] - 1s 2ms/step - loss: 9.5303e-05 - mean_squared_error: 9.5303e-05
# Epoch 89/100
# 352/352 [==============================] - 1s 2ms/step - loss: 9.5675e-05 - mean_squared_error: 9.5675e-05
# Epoch 90/100
# 352/352 [==============================] - 1s 2ms/step - loss: 9.6469e-05 - mean_squared_error: 9.6469e-05
# Epoch 91/100
# 352/352 [==============================] - 1s 3ms/step - loss: 9.6069e-05 - mean_squared_error: 9.6069e-05
# Epoch 92/100
# 352/352 [==============================] - 1s 2ms/step - loss: 9.4569e-05 - mean_squared_error: 9.4569e-05
# Epoch 93/100
# 352/352 [==============================] - 1s 2ms/step - loss: 9.1297e-05 - mean_squared_error: 9.1297e-05
# Epoch 94/100
# 352/352 [==============================] - 1s 3ms/step - loss: 9.2703e-05 - mean_squared_error: 9.2703e-05
# Epoch 95/100
# 352/352 [==============================] - 1s 3ms/step - loss: 9.1960e-05 - mean_squared_error: 9.1960e-05
# Epoch 96/100
# 352/352 [==============================] - 1s 2ms/step - loss: 1.0079e-04 - mean_squared_error: 1.0079e-04
# Epoch 97/100
# 352/352 [==============================] - 1s 2ms/step - loss: 9.3942e-05 - mean_squared_error: 9.3942e-05
# Epoch 98/100
# 352/352 [==============================] - 1s 2ms/step - loss: 9.5633e-05 - mean_squared_error: 9.5633e-05
# Epoch 99/100
# 352/352 [==============================] - 1s 3ms/step - loss: 9.7986e-05 - mean_squared_error: 9.7986e-05
# Epoch 100/100
# 352/352 [==============================] - 1s 3ms/step - loss: 9.3303e-05 - mean_squared_error: 9.3303e-05

# %%
nn3_predictions = keras_nn3.predict(X_test_ts_prep)
nn3_mse = mean_squared_error(y_test_ts_prep, nn3_predictions)
nn3_r2 = r2_score(y_test_ts_prep, nn3_predictions)
print("NN MSE:", nn3_mse, "NN R2:", nn3_r2)

plt.plot(np.arange(y.values.min(),y.values.max(),0.001), np.arange(y.values.min(),y.values.max(),0.001), c='k', linestyle='--', linewidth=1)
plt.scatter(
    y_test_ts_prep, nn3_predictions, alpha=0.1, s=1,c=inputs[color_column].loc[y_test_ts_prep.index], cmap=cmap,
    )
plt.colorbar(label=color_column)
plt.xlabel('True Frequency')
plt.ylabel('Predicted Frequency')
plt.show()
# Out:
# NN MSE: 0.00010762790098981298 NN R2: 0.857658980114192

# %% [markdown]
# # Hyperparameter tuning

# %%
import optuna 
def objective_cb(trial):
    params = {
        #"task_type" : "GPU",
        "iterations": trial.suggest_int("iterations", 500, 2000),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 0.1, 10, log=True),
        "learning_rate": trial.suggest_float("learning_rate",0.01, 0.1, log=True),
        "depth": trial.suggest_int("depth", 1, 12),
        #"subsample": trial.suggest_float("subsample", 0.05, 1.0),
        #"colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.05, 1.0),
    }

    model = cb.CatBoostRegressor(**params, silent=True)
    model.fit(X_tr_ts, y_tr_ts)
    predictions = model.predict(X_test_ts)
    mse = mean_squared_error(y_test_ts, predictions, squared=True)
    return mse

study = optuna.create_study(direction='minimize', study_name='catboost_optimization')
study.optimize(objective_cb, n_trials=50, n_jobs=-1, timeout=600)

print(study.best_value)
print(study.best_params)
# Out:
# [I 2023-07-28 13:26:07,007] A new study created in memory with name: catboost_optimization
# [I 2023-07-28 13:26:21,405] Trial 1 finished with value: 9.893905199392828e-05 and parameters: {'iterations': 601, 'l2_leaf_reg': 7.306949497282726, 'learning_rate': 0.020364082920939747, 'depth': 5}. Best is trial 1 with value: 9.893905199392828e-05.
# [I 2023-07-28 13:26:35,555] Trial 2 finished with value: 8.763811274198158e-05 and parameters: {'iterations': 1329, 'l2_leaf_reg': 0.16920134589771987, 'learning_rate': 0.04546018125733392, 'depth': 5}. Best is trial 2 with value: 8.763811274198158e-05.
# [I 2023-07-28 13:26:43,039] Trial 0 finished with value: 9.44249223061108e-05 and parameters: {'iterations': 848, 'l2_leaf_reg': 7.242746650502016, 'learning_rate': 0.01151843286287543, 'depth': 7}. Best is trial 2 with value: 8.763811274198158e-05.
# [I 2023-07-28 13:26:55,065] Trial 9 finished with value: 9.022057761650392e-05 and parameters: {'iterations': 1356, 'l2_leaf_reg': 3.220652713459409, 'learning_rate': 0.05565152761910749, 'depth': 3}. Best is trial 2 with value: 8.763811274198158e-05.
# [I 2023-07-28 13:27:02,351] Trial 11 finished with value: 0.000145820811363798 and parameters: {'iterations': 696, 'l2_leaf_reg': 2.9671684252830097, 'learning_rate': 0.06097588400765301, 'depth': 1}. Best is trial 2 with value: 8.763811274198158e-05.
# [I 2023-07-28 13:27:10,717] Trial 12 finished with value: 0.00017560346280139826 and parameters: {'iterations': 858, 'l2_leaf_reg': 0.3647633700333308, 'learning_rate': 0.022675471543296848, 'depth': 1}. Best is trial 2 with value: 8.763811274198158e-05.
# [I 2023-07-28 13:27:21,915] Trial 3 finished with value: 9.191891806690399e-05 and parameters: {'iterations': 651, 'l2_leaf_reg': 4.689953617043962, 'learning_rate': 0.011641030501913866, 'depth': 9}. Best is trial 2 with value: 8.763811274198158e-05.
# [I 2023-07-28 13:27:25,811] Trial 7 finished with value: 8.963661439215405e-05 and parameters: {'iterations': 1905, 'l2_leaf_reg': 0.23956026088771487, 'learning_rate': 0.05582594601415637, 'depth': 7}. Best is trial 2 with value: 8.763811274198158e-05.
# [I 2023-07-28 13:27:32,864] Trial 13 finished with value: 9.113288306467106e-05 and parameters: {'iterations': 1538, 'l2_leaf_reg': 0.28024960148383865, 'learning_rate': 0.041656138565323936, 'depth': 3}. Best is trial 2 with value: 8.763811274198158e-05.
# [I 2023-07-28 13:27:39,998] Trial 15 finished with value: 0.00010709533559885059 and parameters: {'iterations': 1362, 'l2_leaf_reg': 0.47101393317193824, 'learning_rate': 0.025902558196220067, 'depth': 2}. Best is trial 2 with value: 8.763811274198158e-05.
# [I 2023-07-28 13:28:33,808] Trial 14 finished with value: 8.767443266269868e-05 and parameters: {'iterations': 1676, 'l2_leaf_reg': 1.2238612762830332, 'learning_rate': 0.015145994268443182, 'depth': 7}. Best is trial 2 with value: 8.763811274198158e-05.
# [I 2023-07-28 13:28:42,283] Trial 6 finished with value: 8.744233445859084e-05 and parameters: {'iterations': 511, 'l2_leaf_reg': 0.6802885290928246, 'learning_rate': 0.05445124502312814, 'depth': 10}. Best is trial 6 with value: 8.744233445859084e-05.
# [I 2023-07-28 13:29:18,235] Trial 16 finished with value: 9.080710169446398e-05 and parameters: {'iterations': 788, 'l2_leaf_reg': 0.1351906436698046, 'learning_rate': 0.08618959894806719, 'depth': 9}. Best is trial 6 with value: 8.744233445859084e-05.
# [I 2023-07-28 13:36:34,676] Trial 8 finished with value: 9.110250793751762e-05 and parameters: {'iterations': 1201, 'l2_leaf_reg': 0.3853060608260599, 'learning_rate': 0.059049135153110895, 'depth': 11}. Best is trial 6 with value: 8.744233445859084e-05.
# [I 2023-07-28 13:40:51,319] Trial 5 finished with value: 9.176519298166513e-05 and parameters: {'iterations': 1814, 'l2_leaf_reg': 0.8599243391042845, 'learning_rate': 0.05074676063267128, 'depth': 11}. Best is trial 6 with value: 8.744233445859084e-05.
# [I 2023-07-28 13:44:01,868] Trial 19 finished with value: 9.720103141485853e-05 and parameters: {'iterations': 1124, 'l2_leaf_reg': 0.1568073894605185, 'learning_rate': 0.09625425064496669, 'depth': 12}. Best is trial 6 with value: 8.744233445859084e-05.
# [I 2023-07-28 13:45:59,016] Trial 20 finished with value: 8.991813377834921e-05 and parameters: {'iterations': 1120, 'l2_leaf_reg': 0.10325394273136955, 'learning_rate': 0.03577408933164078, 'depth': 12}. Best is trial 6 with value: 8.744233445859084e-05.
# [I 2023-07-28 13:48:27,331] Trial 4 finished with value: 8.962879112505672e-05 and parameters: {'iterations': 1827, 'l2_leaf_reg': 0.6484929096721475, 'learning_rate': 0.027081785736448566, 'depth': 12}. Best is trial 6 with value: 8.744233445859084e-05.
# [I 2023-07-28 13:49:21,646] Trial 10 finished with value: 8.807403948257881e-05 and parameters: {'iterations': 1830, 'l2_leaf_reg': 2.9648096806943522, 'learning_rate': 0.029641928251709738, 'depth': 12}. Best is trial 6 with value: 8.744233445859084e-05.
# [I 2023-07-28 13:49:22,816] Trial 17 finished with value: 9.763857906194979e-05 and parameters: {'iterations': 1756, 'l2_leaf_reg': 0.11144289442124196, 'learning_rate': 0.09957370922896736, 'depth': 12}. Best is trial 6 with value: 8.744233445859084e-05.
# [I 2023-07-28 13:49:33,124] Trial 18 finished with value: 9.664125286891588e-05 and parameters: {'iterations': 1761, 'l2_leaf_reg': 0.11595879652842747, 'learning_rate': 0.09719314763118038, 'depth': 12}. Best is trial 6 with value: 8.744233445859084e-05.
# 8.744233445859084e-05
# {'iterations': 511, 'l2_leaf_reg': 0.6802885290928246, 'learning_rate': 0.05445124502312814, 'depth': 10}

# %%
best_params = study.best_params
cb_regr_opt = cb.CatBoostRegressor(**best_params)
cb_regr_opt.fit(X_tr_ts, y_tr_ts)
# Out:
# 0:	learn: 0.0260364	total: 46.4ms	remaining: 23.7s
# 1:	learn: 0.0250116	total: 94.8ms	remaining: 24.1s
# 2:	learn: 0.0239828	total: 143ms	remaining: 24.2s
# 3:	learn: 0.0230883	total: 191ms	remaining: 24.2s
# 4:	learn: 0.0221609	total: 232ms	remaining: 23.5s
# 5:	learn: 0.0213157	total: 279ms	remaining: 23.5s
# 6:	learn: 0.0205181	total: 322ms	remaining: 23.2s
# 7:	learn: 0.0197469	total: 361ms	remaining: 22.7s
# 8:	learn: 0.0190399	total: 415ms	remaining: 23.1s
# 9:	learn: 0.0184055	total: 466ms	remaining: 23.4s
# 10:	learn: 0.0177947	total: 513ms	remaining: 23.3s
# 11:	learn: 0.0171915	total: 569ms	remaining: 23.7s
# 12:	learn: 0.0166685	total: 625ms	remaining: 23.9s
# 13:	learn: 0.0161493	total: 672ms	remaining: 23.9s
# 14:	learn: 0.0156823	total: 726ms	remaining: 24s
# 15:	learn: 0.0152330	total: 777ms	remaining: 24s
# 16:	learn: 0.0148027	total: 820ms	remaining: 23.8s
# 17:	learn: 0.0143909	total: 863ms	remaining: 23.6s
# 18:	learn: 0.0140580	total: 920ms	remaining: 23.8s
# 19:	learn: 0.0136998	total: 965ms	remaining: 23.7s
# 20:	learn: 0.0133692	total: 1.01s	remaining: 23.7s
# 21:	learn: 0.0130528	total: 1.06s	remaining: 23.6s
# 22:	learn: 0.0127853	total: 1.11s	remaining: 23.6s
# 23:	learn: 0.0125161	total: 1.16s	remaining: 23.5s
# 24:	learn: 0.0122770	total: 1.2s	remaining: 23.3s
# 25:	learn: 0.0120464	total: 1.25s	remaining: 23.3s
# 26:	learn: 0.0118374	total: 1.29s	remaining: 23.2s
# 27:	learn: 0.0116399	total: 1.34s	remaining: 23.1s
# 28:	learn: 0.0114596	total: 1.39s	remaining: 23.1s
# 29:	learn: 0.0112975	total: 1.44s	remaining: 23s
# 30:	learn: 0.0111444	total: 1.48s	remaining: 23s
# 31:	learn: 0.0109936	total: 1.53s	remaining: 22.9s
# 32:	learn: 0.0108465	total: 1.58s	remaining: 22.8s
# 33:	learn: 0.0107292	total: 1.62s	remaining: 22.7s
# 34:	learn: 0.0106117	total: 1.66s	remaining: 22.6s
# 35:	learn: 0.0104767	total: 1.71s	remaining: 22.6s
# 36:	learn: 0.0103532	total: 1.76s	remaining: 22.5s
# 37:	learn: 0.0102610	total: 1.81s	remaining: 22.5s
# 38:	learn: 0.0101556	total: 1.85s	remaining: 22.5s
# 39:	learn: 0.0100699	total: 1.91s	remaining: 22.5s
# 40:	learn: 0.0099846	total: 1.96s	remaining: 22.4s
# 41:	learn: 0.0099079	total: 2s	remaining: 22.3s
# 42:	learn: 0.0098170	total: 2.04s	remaining: 22.3s
# 43:	learn: 0.0097572	total: 2.08s	remaining: 22.1s
# 44:	learn: 0.0096879	total: 2.13s	remaining: 22.1s
# 45:	learn: 0.0096244	total: 2.18s	remaining: 22s
# 46:	learn: 0.0095602	total: 2.22s	remaining: 22s
# 47:	learn: 0.0095115	total: 2.28s	remaining: 22s
# 48:	learn: 0.0094602	total: 2.32s	remaining: 21.9s
# 49:	learn: 0.0094173	total: 2.38s	remaining: 21.9s
# 50:	learn: 0.0093584	total: 2.42s	remaining: 21.8s
# 51:	learn: 0.0093171	total: 2.48s	remaining: 21.9s
# 52:	learn: 0.0092619	total: 2.52s	remaining: 21.8s
# 53:	learn: 0.0092139	total: 2.57s	remaining: 21.7s
# 54:	learn: 0.0091777	total: 2.61s	remaining: 21.7s
# 55:	learn: 0.0091384	total: 2.67s	remaining: 21.7s
# 56:	learn: 0.0090986	total: 2.72s	remaining: 21.7s
# 57:	learn: 0.0090654	total: 2.77s	remaining: 21.6s
# 58:	learn: 0.0090289	total: 2.82s	remaining: 21.6s
# 59:	learn: 0.0089997	total: 2.87s	remaining: 21.5s
# 60:	learn: 0.0089677	total: 2.91s	remaining: 21.5s
# 61:	learn: 0.0089353	total: 2.95s	remaining: 21.4s
# 62:	learn: 0.0089048	total: 3s	remaining: 21.3s
# 63:	learn: 0.0088768	total: 3.04s	remaining: 21.2s
# 64:	learn: 0.0088509	total: 3.1s	remaining: 21.2s
# 65:	learn: 0.0088301	total: 3.14s	remaining: 21.2s
# 66:	learn: 0.0088088	total: 3.19s	remaining: 21.1s
# 67:	learn: 0.0087875	total: 3.24s	remaining: 21.1s
# 68:	learn: 0.0087645	total: 3.29s	remaining: 21s
# 69:	learn: 0.0087398	total: 3.33s	remaining: 21s
# 70:	learn: 0.0087132	total: 3.38s	remaining: 20.9s
# 71:	learn: 0.0086955	total: 3.43s	remaining: 20.9s
# 72:	learn: 0.0086749	total: 3.47s	remaining: 20.8s
# 73:	learn: 0.0086511	total: 3.52s	remaining: 20.8s
# 74:	learn: 0.0086358	total: 3.56s	remaining: 20.7s
# 75:	learn: 0.0086186	total: 3.61s	remaining: 20.6s
# 76:	learn: 0.0086029	total: 3.65s	remaining: 20.6s
# 77:	learn: 0.0085824	total: 3.69s	remaining: 20.5s
# 78:	learn: 0.0085577	total: 3.74s	remaining: 20.4s
# 79:	learn: 0.0085405	total: 3.78s	remaining: 20.3s
# 80:	learn: 0.0085254	total: 3.83s	remaining: 20.3s
# 81:	learn: 0.0085074	total: 3.88s	remaining: 20.3s
# 82:	learn: 0.0084883	total: 3.92s	remaining: 20.2s
# 83:	learn: 0.0084776	total: 3.96s	remaining: 20.1s
# 84:	learn: 0.0084622	total: 4s	remaining: 20.1s
# 85:	learn: 0.0084414	total: 4.05s	remaining: 20s
# 86:	learn: 0.0084312	total: 4.09s	remaining: 19.9s
# 87:	learn: 0.0084118	total: 4.14s	remaining: 19.9s
# 88:	learn: 0.0084009	total: 4.2s	remaining: 19.9s
# 89:	learn: 0.0083915	total: 4.24s	remaining: 19.8s
# 90:	learn: 0.0083745	total: 4.29s	remaining: 19.8s
# 91:	learn: 0.0083565	total: 4.34s	remaining: 19.8s
# 92:	learn: 0.0083400	total: 4.39s	remaining: 19.8s
# 93:	learn: 0.0083204	total: 4.44s	remaining: 19.7s
# 94:	learn: 0.0083100	total: 4.49s	remaining: 19.7s
# 95:	learn: 0.0082992	total: 4.55s	remaining: 19.7s
# 96:	learn: 0.0082857	total: 4.6s	remaining: 19.6s
# 97:	learn: 0.0082693	total: 4.64s	remaining: 19.6s
# 98:	learn: 0.0082595	total: 4.69s	remaining: 19.5s
# 99:	learn: 0.0082507	total: 4.74s	remaining: 19.5s
# 100:	learn: 0.0082396	total: 4.79s	remaining: 19.4s
# 101:	learn: 0.0082313	total: 4.83s	remaining: 19.4s
# 102:	learn: 0.0082255	total: 4.88s	remaining: 19.3s
# 103:	learn: 0.0082090	total: 4.92s	remaining: 19.3s
# 104:	learn: 0.0081976	total: 4.97s	remaining: 19.2s
# 105:	learn: 0.0081809	total: 5.02s	remaining: 19.2s
# 106:	learn: 0.0081707	total: 5.07s	remaining: 19.1s
# 107:	learn: 0.0081587	total: 5.12s	remaining: 19.1s
# 108:	learn: 0.0081490	total: 5.17s	remaining: 19.1s
# 109:	learn: 0.0081387	total: 5.21s	remaining: 19s
# 110:	learn: 0.0081225	total: 5.25s	remaining: 18.9s
# 111:	learn: 0.0081140	total: 5.3s	remaining: 18.9s
# 112:	learn: 0.0081016	total: 5.35s	remaining: 18.8s
# 113:	learn: 0.0080975	total: 5.4s	remaining: 18.8s
# 114:	learn: 0.0080894	total: 5.45s	remaining: 18.8s
# 115:	learn: 0.0080722	total: 5.49s	remaining: 18.7s
# 116:	learn: 0.0080610	total: 5.54s	remaining: 18.6s
# 117:	learn: 0.0080539	total: 5.58s	remaining: 18.6s
# 118:	learn: 0.0080415	total: 5.63s	remaining: 18.6s
# 119:	learn: 0.0080309	total: 5.68s	remaining: 18.5s
# 120:	learn: 0.0080211	total: 5.73s	remaining: 18.5s
# 121:	learn: 0.0080129	total: 5.78s	remaining: 18.4s
# 122:	learn: 0.0080058	total: 5.83s	remaining: 18.4s
# 123:	learn: 0.0079988	total: 5.88s	remaining: 18.4s
# 124:	learn: 0.0079917	total: 5.93s	remaining: 18.3s
# 125:	learn: 0.0079857	total: 5.97s	remaining: 18.3s
# 126:	learn: 0.0079773	total: 6.01s	remaining: 18.2s
# 127:	learn: 0.0079692	total: 6.05s	remaining: 18.1s
# 128:	learn: 0.0079593	total: 6.09s	remaining: 18s
# 129:	learn: 0.0079483	total: 6.13s	remaining: 18s
# 130:	learn: 0.0079404	total: 6.17s	remaining: 17.9s
# 131:	learn: 0.0079303	total: 6.23s	remaining: 17.9s
# 132:	learn: 0.0079231	total: 6.28s	remaining: 17.8s
# 133:	learn: 0.0079165	total: 6.32s	remaining: 17.8s
# 134:	learn: 0.0079099	total: 6.36s	remaining: 17.7s
# 135:	learn: 0.0079016	total: 6.41s	remaining: 17.7s
# 136:	learn: 0.0078959	total: 6.46s	remaining: 17.6s
# 137:	learn: 0.0078868	total: 6.5s	remaining: 17.6s
# 138:	learn: 0.0078774	total: 6.54s	remaining: 17.5s
# 139:	learn: 0.0078689	total: 6.59s	remaining: 17.5s
# 140:	learn: 0.0078617	total: 6.63s	remaining: 17.4s
# 141:	learn: 0.0078453	total: 6.68s	remaining: 17.4s
# 142:	learn: 0.0078363	total: 6.73s	remaining: 17.3s
# 143:	learn: 0.0078243	total: 6.78s	remaining: 17.3s
# 144:	learn: 0.0078104	total: 6.83s	remaining: 17.2s
# 145:	learn: 0.0078058	total: 6.87s	remaining: 17.2s
# 146:	learn: 0.0077972	total: 6.92s	remaining: 17.1s
# 147:	learn: 0.0077924	total: 6.97s	remaining: 17.1s
# 148:	learn: 0.0077823	total: 7.01s	remaining: 17s
# 149:	learn: 0.0077668	total: 7.06s	remaining: 17s
# 150:	learn: 0.0077563	total: 7.1s	remaining: 16.9s
# 151:	learn: 0.0077486	total: 7.15s	remaining: 16.9s
# 152:	learn: 0.0077410	total: 7.19s	remaining: 16.8s
# 153:	learn: 0.0077356	total: 7.24s	remaining: 16.8s
# 154:	learn: 0.0077285	total: 7.29s	remaining: 16.7s
# 155:	learn: 0.0077221	total: 7.33s	remaining: 16.7s
# 156:	learn: 0.0077109	total: 7.4s	remaining: 16.7s
# 157:	learn: 0.0077025	total: 7.44s	remaining: 16.6s
# 158:	learn: 0.0076969	total: 7.49s	remaining: 16.6s
# 159:	learn: 0.0076881	total: 7.53s	remaining: 16.5s
# 160:	learn: 0.0076814	total: 7.57s	remaining: 16.5s
# 161:	learn: 0.0076717	total: 7.62s	remaining: 16.4s
# 162:	learn: 0.0076633	total: 7.66s	remaining: 16.4s
# 163:	learn: 0.0076544	total: 7.71s	remaining: 16.3s
# 164:	learn: 0.0076482	total: 7.76s	remaining: 16.3s
# 165:	learn: 0.0076428	total: 7.8s	remaining: 16.2s
# 166:	learn: 0.0076392	total: 7.85s	remaining: 16.2s
# 167:	learn: 0.0076334	total: 7.89s	remaining: 16.1s
# 168:	learn: 0.0076279	total: 7.94s	remaining: 16.1s
# 169:	learn: 0.0076172	total: 7.99s	remaining: 16s
# 170:	learn: 0.0076075	total: 8.04s	remaining: 16s
# 171:	learn: 0.0075994	total: 8.08s	remaining: 15.9s
# 172:	learn: 0.0075930	total: 8.12s	remaining: 15.9s
# 173:	learn: 0.0075853	total: 8.16s	remaining: 15.8s
# 174:	learn: 0.0075807	total: 8.21s	remaining: 15.8s
# 175:	learn: 0.0075735	total: 8.25s	remaining: 15.7s
# 176:	learn: 0.0075624	total: 8.29s	remaining: 15.6s
# 177:	learn: 0.0075573	total: 8.34s	remaining: 15.6s
# 178:	learn: 0.0075532	total: 8.37s	remaining: 15.5s
# 179:	learn: 0.0075470	total: 8.41s	remaining: 15.5s
# 180:	learn: 0.0075411	total: 8.44s	remaining: 15.4s
# 181:	learn: 0.0075331	total: 8.48s	remaining: 15.3s
# 182:	learn: 0.0075282	total: 8.54s	remaining: 15.3s
# 183:	learn: 0.0075178	total: 8.59s	remaining: 15.3s
# 184:	learn: 0.0075105	total: 8.62s	remaining: 15.2s
# 185:	learn: 0.0075042	total: 8.69s	remaining: 15.2s
# 186:	learn: 0.0074979	total: 8.73s	remaining: 15.1s
# 187:	learn: 0.0074936	total: 8.78s	remaining: 15.1s
# 188:	learn: 0.0074847	total: 8.82s	remaining: 15s
# 189:	learn: 0.0074763	total: 8.87s	remaining: 15s
# 190:	learn: 0.0074701	total: 8.92s	remaining: 14.9s
# 191:	learn: 0.0074599	total: 8.96s	remaining: 14.9s
# 192:	learn: 0.0074527	total: 9.01s	remaining: 14.8s
# 193:	learn: 0.0074477	total: 9.06s	remaining: 14.8s
# 194:	learn: 0.0074414	total: 9.1s	remaining: 14.7s
# 195:	learn: 0.0074317	total: 9.15s	remaining: 14.7s
# 196:	learn: 0.0074242	total: 9.2s	remaining: 14.7s
# 197:	learn: 0.0074162	total: 9.24s	remaining: 14.6s
# 198:	learn: 0.0074099	total: 9.28s	remaining: 14.6s
# 199:	learn: 0.0074076	total: 9.34s	remaining: 14.5s
# 200:	learn: 0.0074002	total: 9.39s	remaining: 14.5s
# 201:	learn: 0.0073946	total: 9.43s	remaining: 14.4s
# 202:	learn: 0.0073855	total: 9.49s	remaining: 14.4s
# 203:	learn: 0.0073799	total: 9.53s	remaining: 14.3s
# 204:	learn: 0.0073687	total: 9.57s	remaining: 14.3s
# 205:	learn: 0.0073630	total: 9.61s	remaining: 14.2s
# 206:	learn: 0.0073567	total: 9.66s	remaining: 14.2s
# 207:	learn: 0.0073466	total: 9.7s	remaining: 14.1s
# 208:	learn: 0.0073387	total: 9.74s	remaining: 14.1s
# 209:	learn: 0.0073309	total: 9.79s	remaining: 14s
# 210:	learn: 0.0073201	total: 9.83s	remaining: 14s
# 211:	learn: 0.0073124	total: 9.88s	remaining: 13.9s
# 212:	learn: 0.0073074	total: 9.92s	remaining: 13.9s
# 213:	learn: 0.0073010	total: 9.96s	remaining: 13.8s
# 214:	learn: 0.0072952	total: 10s	remaining: 13.8s
# 215:	learn: 0.0072902	total: 10.1s	remaining: 13.7s
# 216:	learn: 0.0072847	total: 10.1s	remaining: 13.7s
# 217:	learn: 0.0072776	total: 10.2s	remaining: 13.7s
# 218:	learn: 0.0072677	total: 10.2s	remaining: 13.6s
# 219:	learn: 0.0072612	total: 10.3s	remaining: 13.6s
# 220:	learn: 0.0072564	total: 10.3s	remaining: 13.5s
# 221:	learn: 0.0072485	total: 10.3s	remaining: 13.5s
# 222:	learn: 0.0072403	total: 10.4s	remaining: 13.4s
# 223:	learn: 0.0072365	total: 10.4s	remaining: 13.4s
# 224:	learn: 0.0072278	total: 10.5s	remaining: 13.3s
# 225:	learn: 0.0072219	total: 10.5s	remaining: 13.3s
# 226:	learn: 0.0072172	total: 10.6s	remaining: 13.2s
# 227:	learn: 0.0072095	total: 10.6s	remaining: 13.2s
# 228:	learn: 0.0072024	total: 10.7s	remaining: 13.1s
# 229:	learn: 0.0071960	total: 10.7s	remaining: 13.1s
# 230:	learn: 0.0071883	total: 10.8s	remaining: 13s
# 231:	learn: 0.0071805	total: 10.8s	remaining: 13s
# 232:	learn: 0.0071759	total: 10.8s	remaining: 12.9s
# 233:	learn: 0.0071684	total: 10.9s	remaining: 12.9s
# 234:	learn: 0.0071619	total: 10.9s	remaining: 12.8s
# 235:	learn: 0.0071577	total: 11s	remaining: 12.8s
# 236:	learn: 0.0071497	total: 11s	remaining: 12.7s
# 237:	learn: 0.0071427	total: 11.1s	remaining: 12.7s
# 238:	learn: 0.0071343	total: 11.1s	remaining: 12.6s
# 239:	learn: 0.0071297	total: 11.2s	remaining: 12.6s
# 240:	learn: 0.0071227	total: 11.2s	remaining: 12.6s
# 241:	learn: 0.0071171	total: 11.3s	remaining: 12.5s
# 242:	learn: 0.0071068	total: 11.3s	remaining: 12.5s
# 243:	learn: 0.0071001	total: 11.4s	remaining: 12.5s
# 244:	learn: 0.0070961	total: 11.4s	remaining: 12.4s
# 245:	learn: 0.0070906	total: 11.5s	remaining: 12.4s
# 246:	learn: 0.0070819	total: 11.5s	remaining: 12.3s
# 247:	learn: 0.0070748	total: 11.6s	remaining: 12.3s
# 248:	learn: 0.0070709	total: 11.6s	remaining: 12.2s
# 249:	learn: 0.0070645	total: 11.7s	remaining: 12.2s
# 250:	learn: 0.0070585	total: 11.7s	remaining: 12.1s
# 251:	learn: 0.0070525	total: 11.7s	remaining: 12.1s
# 252:	learn: 0.0070473	total: 11.8s	remaining: 12s
# 253:	learn: 0.0070397	total: 11.8s	remaining: 12s
# 254:	learn: 0.0070328	total: 11.9s	remaining: 11.9s
# 255:	learn: 0.0070278	total: 11.9s	remaining: 11.9s
# 256:	learn: 0.0070193	total: 12s	remaining: 11.8s
# 257:	learn: 0.0070097	total: 12s	remaining: 11.8s
# 258:	learn: 0.0070056	total: 12.1s	remaining: 11.7s
# 259:	learn: 0.0069992	total: 12.1s	remaining: 11.7s
# 260:	learn: 0.0069937	total: 12.2s	remaining: 11.6s
# 261:	learn: 0.0069849	total: 12.2s	remaining: 11.6s
# 262:	learn: 0.0069761	total: 12.3s	remaining: 11.6s
# 263:	learn: 0.0069687	total: 12.3s	remaining: 11.5s
# 264:	learn: 0.0069601	total: 12.4s	remaining: 11.5s
# 265:	learn: 0.0069536	total: 12.4s	remaining: 11.4s
# 266:	learn: 0.0069464	total: 12.5s	remaining: 11.4s
# 267:	learn: 0.0069358	total: 12.5s	remaining: 11.3s
# 268:	learn: 0.0069328	total: 12.6s	remaining: 11.3s
# 269:	learn: 0.0069272	total: 12.6s	remaining: 11.3s
# 270:	learn: 0.0069196	total: 12.7s	remaining: 11.2s
# 271:	learn: 0.0069140	total: 12.7s	remaining: 11.2s
# 272:	learn: 0.0069061	total: 12.8s	remaining: 11.1s
# 273:	learn: 0.0069031	total: 12.8s	remaining: 11.1s
# 274:	learn: 0.0068968	total: 12.8s	remaining: 11s
# 275:	learn: 0.0068907	total: 12.9s	remaining: 11s
# 276:	learn: 0.0068811	total: 12.9s	remaining: 10.9s
# 277:	learn: 0.0068727	total: 13s	remaining: 10.9s
# 278:	learn: 0.0068678	total: 13s	remaining: 10.8s
# 279:	learn: 0.0068626	total: 13.1s	remaining: 10.8s
# 280:	learn: 0.0068571	total: 13.1s	remaining: 10.7s
# 281:	learn: 0.0068519	total: 13.2s	remaining: 10.7s
# 282:	learn: 0.0068449	total: 13.2s	remaining: 10.7s
# 283:	learn: 0.0068411	total: 13.3s	remaining: 10.6s
# 284:	learn: 0.0068343	total: 13.3s	remaining: 10.6s
# 285:	learn: 0.0068296	total: 13.4s	remaining: 10.5s
# 286:	learn: 0.0068260	total: 13.4s	remaining: 10.5s
# 287:	learn: 0.0068189	total: 13.5s	remaining: 10.4s
# 288:	learn: 0.0068132	total: 13.5s	remaining: 10.4s
# 289:	learn: 0.0068068	total: 13.6s	remaining: 10.3s
# 290:	learn: 0.0068019	total: 13.6s	remaining: 10.3s
# 291:	learn: 0.0067932	total: 13.7s	remaining: 10.2s
# 292:	learn: 0.0067885	total: 13.7s	remaining: 10.2s
# 293:	learn: 0.0067832	total: 13.8s	remaining: 10.2s
# 294:	learn: 0.0067767	total: 13.8s	remaining: 10.1s
# 295:	learn: 0.0067707	total: 13.8s	remaining: 10.1s
# 296:	learn: 0.0067650	total: 13.9s	remaining: 10s
# 297:	learn: 0.0067603	total: 13.9s	remaining: 9.96s
# 298:	learn: 0.0067540	total: 14s	remaining: 9.91s
# 299:	learn: 0.0067463	total: 14s	remaining: 9.87s
# 300:	learn: 0.0067415	total: 14.1s	remaining: 9.82s
# 301:	learn: 0.0067353	total: 14.1s	remaining: 9.78s
# 302:	learn: 0.0067291	total: 14.2s	remaining: 9.73s
# 303:	learn: 0.0067260	total: 14.2s	remaining: 9.68s
# 304:	learn: 0.0067197	total: 14.3s	remaining: 9.64s
# 305:	learn: 0.0067146	total: 14.3s	remaining: 9.59s
# 306:	learn: 0.0067094	total: 14.4s	remaining: 9.55s
# 307:	learn: 0.0067069	total: 14.4s	remaining: 9.5s
# 308:	learn: 0.0066955	total: 14.5s	remaining: 9.45s
# 309:	learn: 0.0066895	total: 14.5s	remaining: 9.41s
# 310:	learn: 0.0066799	total: 14.6s	remaining: 9.36s
# 311:	learn: 0.0066748	total: 14.6s	remaining: 9.31s
# 312:	learn: 0.0066685	total: 14.7s	remaining: 9.27s
# 313:	learn: 0.0066634	total: 14.7s	remaining: 9.22s
# 314:	learn: 0.0066576	total: 14.7s	remaining: 9.17s
# 315:	learn: 0.0066528	total: 14.8s	remaining: 9.12s
# 316:	learn: 0.0066473	total: 14.8s	remaining: 9.07s
# 317:	learn: 0.0066428	total: 14.9s	remaining: 9.03s
# 318:	learn: 0.0066383	total: 14.9s	remaining: 8.98s
# 319:	learn: 0.0066341	total: 15s	remaining: 8.93s
# 320:	learn: 0.0066290	total: 15s	remaining: 8.89s
# 321:	learn: 0.0066229	total: 15.1s	remaining: 8.84s
# 322:	learn: 0.0066201	total: 15.1s	remaining: 8.79s
# 323:	learn: 0.0066115	total: 15.1s	remaining: 8.74s
# 324:	learn: 0.0066053	total: 15.2s	remaining: 8.69s
# 325:	learn: 0.0065992	total: 15.2s	remaining: 8.65s
# 326:	learn: 0.0065937	total: 15.3s	remaining: 8.6s
# 327:	learn: 0.0065894	total: 15.3s	remaining: 8.55s
# 328:	learn: 0.0065856	total: 15.4s	remaining: 8.51s
# 329:	learn: 0.0065797	total: 15.4s	remaining: 8.46s
# 330:	learn: 0.0065734	total: 15.5s	remaining: 8.42s
# 331:	learn: 0.0065675	total: 15.5s	remaining: 8.37s
# 332:	learn: 0.0065622	total: 15.6s	remaining: 8.33s
# 333:	learn: 0.0065542	total: 15.6s	remaining: 8.28s
# 334:	learn: 0.0065478	total: 15.7s	remaining: 8.23s
# 335:	learn: 0.0065424	total: 15.7s	remaining: 8.19s
# 336:	learn: 0.0065351	total: 15.8s	remaining: 8.14s
# 337:	learn: 0.0065293	total: 15.8s	remaining: 8.09s
# 338:	learn: 0.0065215	total: 15.9s	remaining: 8.04s
# 339:	learn: 0.0065112	total: 15.9s	remaining: 8s
# 340:	learn: 0.0065049	total: 15.9s	remaining: 7.95s
# 341:	learn: 0.0065005	total: 16s	remaining: 7.9s
# 342:	learn: 0.0064958	total: 16s	remaining: 7.85s
# 343:	learn: 0.0064901	total: 16.1s	remaining: 7.8s
# 344:	learn: 0.0064847	total: 16.1s	remaining: 7.76s
# 345:	learn: 0.0064802	total: 16.2s	remaining: 7.71s
# 346:	learn: 0.0064767	total: 16.2s	remaining: 7.66s
# 347:	learn: 0.0064736	total: 16.3s	remaining: 7.62s
# 348:	learn: 0.0064666	total: 16.3s	remaining: 7.58s
# 349:	learn: 0.0064640	total: 16.4s	remaining: 7.53s
# 350:	learn: 0.0064588	total: 16.4s	remaining: 7.49s
# 351:	learn: 0.0064548	total: 16.5s	remaining: 7.44s
# 352:	learn: 0.0064496	total: 16.5s	remaining: 7.39s
# 353:	learn: 0.0064430	total: 16.6s	remaining: 7.34s
# 354:	learn: 0.0064380	total: 16.6s	remaining: 7.29s
# 355:	learn: 0.0064316	total: 16.6s	remaining: 7.24s
# 356:	learn: 0.0064230	total: 16.7s	remaining: 7.19s
# 357:	learn: 0.0064205	total: 16.7s	remaining: 7.14s
# 358:	learn: 0.0064138	total: 16.8s	remaining: 7.1s
# 359:	learn: 0.0064072	total: 16.8s	remaining: 7.05s
# 360:	learn: 0.0064023	total: 16.9s	remaining: 7s
# 361:	learn: 0.0063955	total: 16.9s	remaining: 6.96s
# 362:	learn: 0.0063935	total: 17s	remaining: 6.91s
# 363:	learn: 0.0063887	total: 17s	remaining: 6.87s
# 364:	learn: 0.0063832	total: 17.1s	remaining: 6.83s
# 365:	learn: 0.0063781	total: 17.1s	remaining: 6.78s
# 366:	learn: 0.0063719	total: 17.2s	remaining: 6.73s
# 367:	learn: 0.0063691	total: 17.2s	remaining: 6.69s
# 368:	learn: 0.0063643	total: 17.2s	remaining: 6.64s
# 369:	learn: 0.0063597	total: 17.3s	remaining: 6.59s
# 370:	learn: 0.0063558	total: 17.3s	remaining: 6.54s
# 371:	learn: 0.0063503	total: 17.4s	remaining: 6.5s
# 372:	learn: 0.0063453	total: 17.4s	remaining: 6.45s
# 373:	learn: 0.0063433	total: 17.5s	remaining: 6.41s
# 374:	learn: 0.0063333	total: 17.5s	remaining: 6.36s
# 375:	learn: 0.0063286	total: 17.6s	remaining: 6.31s
# 376:	learn: 0.0063232	total: 17.6s	remaining: 6.26s
# 377:	learn: 0.0063174	total: 17.7s	remaining: 6.22s
# 378:	learn: 0.0063132	total: 17.7s	remaining: 6.17s
# 379:	learn: 0.0063088	total: 17.8s	remaining: 6.13s
# 380:	learn: 0.0063058	total: 17.8s	remaining: 6.08s
# 381:	learn: 0.0063006	total: 17.9s	remaining: 6.04s
# 382:	learn: 0.0062964	total: 17.9s	remaining: 5.99s
# 383:	learn: 0.0062905	total: 18s	remaining: 5.95s
# 384:	learn: 0.0062862	total: 18s	remaining: 5.9s
# 385:	learn: 0.0062822	total: 18.1s	remaining: 5.85s
# 386:	learn: 0.0062774	total: 18.1s	remaining: 5.8s
# 387:	learn: 0.0062747	total: 18.2s	remaining: 5.75s
# 388:	learn: 0.0062687	total: 18.2s	remaining: 5.7s
# 389:	learn: 0.0062634	total: 18.2s	remaining: 5.66s
# 390:	learn: 0.0062594	total: 18.3s	remaining: 5.61s
# 391:	learn: 0.0062553	total: 18.3s	remaining: 5.56s
# 392:	learn: 0.0062516	total: 18.3s	remaining: 5.51s
# 393:	learn: 0.0062474	total: 18.4s	remaining: 5.46s
# 394:	learn: 0.0062449	total: 18.4s	remaining: 5.41s
# 395:	learn: 0.0062385	total: 18.5s	remaining: 5.37s
# 396:	learn: 0.0062354	total: 18.5s	remaining: 5.32s
# 397:	learn: 0.0062312	total: 18.6s	remaining: 5.27s
# 398:	learn: 0.0062268	total: 18.6s	remaining: 5.22s
# 399:	learn: 0.0062231	total: 18.6s	remaining: 5.17s
# 400:	learn: 0.0062174	total: 18.7s	remaining: 5.13s
# 401:	learn: 0.0062124	total: 18.7s	remaining: 5.08s
# 402:	learn: 0.0062097	total: 18.8s	remaining: 5.03s
# 403:	learn: 0.0062051	total: 18.8s	remaining: 4.99s
# 404:	learn: 0.0061987	total: 18.9s	remaining: 4.94s
# 405:	learn: 0.0061951	total: 18.9s	remaining: 4.89s
# 406:	learn: 0.0061923	total: 19s	remaining: 4.85s
# 407:	learn: 0.0061887	total: 19s	remaining: 4.8s
# 408:	learn: 0.0061840	total: 19.1s	remaining: 4.75s
# 409:	learn: 0.0061778	total: 19.1s	remaining: 4.71s
# 410:	learn: 0.0061729	total: 19.2s	remaining: 4.66s
# 411:	learn: 0.0061705	total: 19.2s	remaining: 4.61s
# 412:	learn: 0.0061671	total: 19.2s	remaining: 4.57s
# 413:	learn: 0.0061630	total: 19.3s	remaining: 4.52s
# 414:	learn: 0.0061582	total: 19.4s	remaining: 4.48s
# 415:	learn: 0.0061538	total: 19.4s	remaining: 4.43s
# 416:	learn: 0.0061490	total: 19.4s	remaining: 4.38s
# 417:	learn: 0.0061434	total: 19.5s	remaining: 4.34s
# 418:	learn: 0.0061380	total: 19.5s	remaining: 4.29s
# 419:	learn: 0.0061327	total: 19.6s	remaining: 4.24s
# 420:	learn: 0.0061310	total: 19.6s	remaining: 4.19s
# 421:	learn: 0.0061279	total: 19.7s	remaining: 4.15s
# 422:	learn: 0.0061262	total: 19.7s	remaining: 4.1s
# 423:	learn: 0.0061218	total: 19.8s	remaining: 4.05s
# 424:	learn: 0.0061170	total: 19.8s	remaining: 4.01s
# 425:	learn: 0.0061134	total: 19.9s	remaining: 3.96s
# 426:	learn: 0.0061088	total: 19.9s	remaining: 3.91s
# 427:	learn: 0.0061074	total: 19.9s	remaining: 3.87s
# 428:	learn: 0.0061025	total: 20s	remaining: 3.82s
# 429:	learn: 0.0060969	total: 20s	remaining: 3.77s
# 430:	learn: 0.0060941	total: 20.1s	remaining: 3.73s
# 431:	learn: 0.0060896	total: 20.1s	remaining: 3.68s
# 432:	learn: 0.0060861	total: 20.2s	remaining: 3.64s
# 433:	learn: 0.0060832	total: 20.2s	remaining: 3.59s
# 434:	learn: 0.0060807	total: 20.3s	remaining: 3.54s
# 435:	learn: 0.0060758	total: 20.3s	remaining: 3.5s
# 436:	learn: 0.0060703	total: 20.4s	remaining: 3.45s
# 437:	learn: 0.0060666	total: 20.4s	remaining: 3.41s
# 438:	learn: 0.0060622	total: 20.5s	remaining: 3.36s
# 439:	learn: 0.0060568	total: 20.6s	remaining: 3.32s
# 440:	learn: 0.0060513	total: 20.6s	remaining: 3.27s
# 441:	learn: 0.0060505	total: 20.7s	remaining: 3.22s
# 442:	learn: 0.0060456	total: 20.7s	remaining: 3.18s
# 443:	learn: 0.0060409	total: 20.8s	remaining: 3.13s
# 444:	learn: 0.0060339	total: 20.8s	remaining: 3.09s
# 445:	learn: 0.0060296	total: 20.9s	remaining: 3.04s
# 446:	learn: 0.0060251	total: 20.9s	remaining: 2.99s
# 447:	learn: 0.0060207	total: 21s	remaining: 2.95s
# 448:	learn: 0.0060164	total: 21s	remaining: 2.9s
# 449:	learn: 0.0060134	total: 21.1s	remaining: 2.85s
# 450:	learn: 0.0060124	total: 21.1s	remaining: 2.81s
# 451:	learn: 0.0060076	total: 21.2s	remaining: 2.76s
# 452:	learn: 0.0060034	total: 21.2s	remaining: 2.71s
# 453:	learn: 0.0059989	total: 21.3s	remaining: 2.67s
# 454:	learn: 0.0059940	total: 21.3s	remaining: 2.62s
# 455:	learn: 0.0059908	total: 21.4s	remaining: 2.58s
# 456:	learn: 0.0059868	total: 21.4s	remaining: 2.53s
# 457:	learn: 0.0059818	total: 21.4s	remaining: 2.48s
# 458:	learn: 0.0059783	total: 21.5s	remaining: 2.43s
# 459:	learn: 0.0059746	total: 21.5s	remaining: 2.39s
# 460:	learn: 0.0059710	total: 21.6s	remaining: 2.34s
# 461:	learn: 0.0059683	total: 21.6s	remaining: 2.29s
# 462:	learn: 0.0059637	total: 21.7s	remaining: 2.25s
# 463:	learn: 0.0059598	total: 21.7s	remaining: 2.2s
# 464:	learn: 0.0059561	total: 21.8s	remaining: 2.16s
# 465:	learn: 0.0059524	total: 21.9s	remaining: 2.11s
# 466:	learn: 0.0059474	total: 21.9s	remaining: 2.06s
# 467:	learn: 0.0059435	total: 21.9s	remaining: 2.02s
# 468:	learn: 0.0059404	total: 22s	remaining: 1.97s
# 469:	learn: 0.0059344	total: 22.1s	remaining: 1.92s
# 470:	learn: 0.0059302	total: 22.1s	remaining: 1.88s
# 471:	learn: 0.0059274	total: 22.2s	remaining: 1.83s
# 472:	learn: 0.0059249	total: 22.2s	remaining: 1.78s
# 473:	learn: 0.0059227	total: 22.3s	remaining: 1.74s
# 474:	learn: 0.0059202	total: 22.3s	remaining: 1.69s
# 475:	learn: 0.0059180	total: 22.3s	remaining: 1.64s
# 476:	learn: 0.0059138	total: 22.4s	remaining: 1.6s
# 477:	learn: 0.0059082	total: 22.5s	remaining: 1.55s
# 478:	learn: 0.0059041	total: 22.5s	remaining: 1.5s
# 479:	learn: 0.0058983	total: 22.5s	remaining: 1.46s
# 480:	learn: 0.0058938	total: 22.6s	remaining: 1.41s
# 481:	learn: 0.0058906	total: 22.6s	remaining: 1.36s
# 482:	learn: 0.0058893	total: 22.7s	remaining: 1.31s
# 483:	learn: 0.0058841	total: 22.7s	remaining: 1.27s
# 484:	learn: 0.0058798	total: 22.8s	remaining: 1.22s
# 485:	learn: 0.0058763	total: 22.8s	remaining: 1.17s
# 486:	learn: 0.0058717	total: 22.9s	remaining: 1.13s
# 487:	learn: 0.0058677	total: 22.9s	remaining: 1.08s
# 488:	learn: 0.0058629	total: 23s	remaining: 1.03s
# 489:	learn: 0.0058591	total: 23s	remaining: 987ms
# 490:	learn: 0.0058549	total: 23.1s	remaining: 940ms
# 491:	learn: 0.0058520	total: 23.1s	remaining: 893ms
# 492:	learn: 0.0058475	total: 23.2s	remaining: 846ms
# 493:	learn: 0.0058446	total: 23.2s	remaining: 799ms
# 494:	learn: 0.0058404	total: 23.3s	remaining: 752ms
# 495:	learn: 0.0058377	total: 23.3s	remaining: 705ms
# 496:	learn: 0.0058326	total: 23.4s	remaining: 658ms
# 497:	learn: 0.0058298	total: 23.4s	remaining: 611ms
# 498:	learn: 0.0058272	total: 23.5s	remaining: 564ms
# 499:	learn: 0.0058248	total: 23.5s	remaining: 517ms
# 500:	learn: 0.0058221	total: 23.6s	remaining: 470ms
# 501:	learn: 0.0058185	total: 23.6s	remaining: 424ms
# 502:	learn: 0.0058172	total: 23.7s	remaining: 377ms
# 503:	learn: 0.0058129	total: 23.7s	remaining: 330ms
# 504:	learn: 0.0058094	total: 23.8s	remaining: 283ms
# 505:	learn: 0.0058068	total: 23.8s	remaining: 235ms
# 506:	learn: 0.0058032	total: 23.9s	remaining: 188ms
# 507:	learn: 0.0058024	total: 23.9s	remaining: 141ms
# 508:	learn: 0.0057993	total: 24s	remaining: 94.2ms
# 509:	learn: 0.0057964	total: 24s	remaining: 47.1ms
# 510:	learn: 0.0057933	total: 24.1s	remaining: 0us

# %%
cb_regr_opt_predictions = cb_regr_opt.predict(X_test_ts)
cb_regr_opt_mse = mean_squared_error(y_test_ts, cb_regr_opt_predictions)
cb_regr_opt_r2 = r2_score(y_test_ts, cb_regr_opt_predictions)
print("CB opt MSE:", cb_regr_opt_mse, "CB opt R2:", cb_regr_opt_r2)

plt.plot(np.arange(y.values.min(),y.values.max(),0.001), np.arange(y.values.min(),y.values.max(),0.001), c='k', linestyle='--', linewidth=1)
plt.scatter(
    y_test_ts, cb_regr_opt_predictions, alpha=0.1, s=1,c=inputs[color_column].loc[y_test_ts.index], cmap=cmap,
    )
plt.colorbar(label=color_column)
plt.xlabel('True Frequency')
plt.ylabel('Predicted Frequency')
plt.show()
# Out:
# CB opt MSE: 8.744233445859084e-05 CB opt R2: 0.8843549771614534

# %%
#Hyperparameter optimization

#Hyperopt functions for hyperparameter optimizations
from sklearn.pipeline import Pipeline
from hyperopt import hp,fmin,tpe,STATUS_OK,Trials
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor
from oma_tracking.models.utils import convert_dict
from oma_tracking.data.preprocessing import AngleTransformer, sin_cos_angle_inputs


XGB_optimizations = {}

seed = 24
def objective_xgb(space):
    model = Pipeline(
            steps=[
                ('preprocessing_angles', AngleTransformer(angles = ['winddirection', 'yaw'])),
                ('regressor', XGBRegressor(
                                 n_estimators = space['n_estimators'],
                                 max_depth = space['max_depth'],
                                 learning_rate = space['learning_rate'],
                                 colsample_bytree = space['colsample_bytree'],
                                 )
                )
            ]
        )
    score = cross_val_score(model,  X_tr_ts, y_tr_ts, cv=5, scoring='neg_mean_squared_error').mean()
    # We aim to maximize r2 score, therefore we return it as a negative value
    return {'loss': -score, 'status': STATUS_OK }

def optimize_xgb(trial):
    space = {
        'n_estimators':hp.uniformint('n_estimators',10,1000),
        'max_depth':hp.uniformint('max_depth',2,20),
        'learning_rate':hp.uniform('learning_rate',0.001,0.5),
        'colsample_bytree': hp.uniform('colsample_bytree',0.1, 1),
    }
    best = \
        fmin(
            fn = objective_xgb,
            space = space,
            algo = tpe.suggest,
            trials = trial,
            max_evals = 20,
            )
    return best
mode = 'SS1'
trial2=Trials()
XGB_optimizations[mode] = optimize_xgb(trial2)
XGB_optimizations[mode] = convert_dict(XGB_optimizations)[mode]
# Out:
# 100%|██████████| 20/20 [06:48<00:00, 20.41s/trial, best loss: 0.00046896962736178943]

# %%
regr_xgb_optimized = \
                Pipeline(
                    steps=[
                        ('preprocessing_angles', AngleTransformer(angles = ['winddirection', 'yaw'])),
                        ('regressor', XGBRegressor(
                            n_estimators = XGB_optimizations[mode]['n_estimators'],
                            max_depth = XGB_optimizations[mode]['max_depth'],
                            learning_rate = XGB_optimizations[mode]['learning_rate'],
                            colsample_bytree = XGB_optimizations[mode]['colsample_bytree'],
                            )
                        )
                    ]
                )

regr_xgb_optimized.fit(X_tr_ts, y_tr_ts)

regr_xgb_optimized_pred = regr_xgb_optimized.predict(X_test_ts)
regr_xgb_optimized_mse = mean_squared_error(y_test_ts, regr_xgb_optimized_pred)
regr_xgb_optimized_r2 = r2_score(y_test_ts, regr_xgb_optimized_pred)
print("XGBRegressor Optimized MSE:", regr_xgb_optimized_mse, "XGBRegressor Optimized R2:", regr_xgb_optimized_r2)
# Out:
# XGBRegressor Optimized MSE: 0.00011383802416066513 XGBRegressor Optimized R2: 0.8494459121492295

# %%
#Hyperparameter optimization

#Hyperopt functions for hyperparameter optimizations

from hyperopt import hp,fmin,tpe,STATUS_OK,Trials
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor
from oma_tracking.models.utils import convert_dict
RF_optimizations = {}

seed = 24
def objective_rf(space):
    model = Pipeline(
            steps=[
                ('preprocessing_angles', AngleTransformer(angles = ['winddirection', 'yaw'])),
                ('regressor', RandomForestRegressor(
                                 n_estimators = space['n_estimators'],
                                 max_depth = space['max_depth'],
                                 min_samples_split = space['min_samples_split'],
                                 )
                )
            ]
        )
    score = cross_val_score(model,   X_tr_ts, y_tr_ts, cv=5, scoring='neg_mean_squared_error').mean()
    # We aim to maximize r2 score, therefore we return it as a negative value
    return {'loss': -score, 'status': STATUS_OK }

def optimize_rf(trial):
    space = {
        'n_estimators': hp.uniformint('n_estimators',10,500),
        'max_depth': hp.uniformint('max_depth',2,20),
        'min_samples_split': hp.uniformint('min_samples_split',2,20)
    }
    best = \
        fmin(
            fn = objective_rf,
            space = space,
            algo = tpe.suggest,
            trials = trial,
            max_evals = 20,
            )
    return best
        
trial2=Trials()
RF_optimizations[mode] = optimize_rf(trial2)
RF_optimizations[mode] = convert_dict(RF_optimizations)[mode]
# Out:
#  10%|█         | 2/20 [08:10<1:13:35, 245.33s/trial, best loss: 0.0006264979277034795]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 46
#      43     return best
#      45 trial2=Trials()
# ---> 46 RF_optimizations[mode] = optimize_rf(trial2)
#      47 RF_optimizations[mode] = convert_dict(RF_optimizations)[mode]
#
# Cell In[33], line 36, in optimize_rf(trial)
#      29 def optimize_rf(trial):
#      30     space = {
#      31         'n_estimators': hp.uniformint('n_estimators',10,500),
#      32         'max_depth': hp.uniformint('max_depth',2,20),
#      33         'min_samples_split': hp.uniformint('min_samples_split',2,20)
#      34     }
#      35     best = \
# ---> 36         fmin(
#      37             fn = objective_rf,
#      38             space = space,
#      39             algo = tpe.suggest,
#      40             trials = trial,
#      41             max_evals = 20,
#      42             )
#      43     return best
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\hyperopt\fmin.py:507, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     504 validate_loss_threshold(loss_threshold)
#     506 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 507     return trials.fmin(
#     508         fn,
#     509         space,
#     510         algo=algo,
#     511         max_evals=max_evals,
#     512         timeout=timeout,
#     513         loss_threshold=loss_threshold,
#     514         max_queue_len=max_queue_len,
#     515         rstate=rstate,
#     516         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     517         verbose=verbose,
#     518         catch_eval_exceptions=catch_eval_exceptions,
#     519         return_argmin=return_argmin,
#     520         show_progressbar=show_progressbar,
#     521         early_stop_fn=early_stop_fn,
#     522         trials_save_file=trials_save_file,
#     523     )
#     525 if trials is None:
#     526     if os.path.exists(trials_save_file):
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\hyperopt\base.py:682, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     677 # -- Stop-gap implementation!
#     678 #    fmin should have been a Trials method in the first place
#     679 #    but for now it's still sitting in another file.
#     680 from .fmin import fmin
# --> 682 return fmin(
#     683     fn,
#     684     space,
#     685     algo,
#     686     max_evals,
#     687     timeout=timeout,
#     688     loss_threshold=loss_threshold,
#     689     trials=self,
#     690     rstate=rstate,
#     691     verbose=verbose,
#     692     max_queue_len=max_queue_len,
#     693     allow_trials_fmin=False,  # -- prevent recursion
#     694     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     695     catch_eval_exceptions=catch_eval_exceptions,
#     696     return_argmin=return_argmin,
#     697     show_progressbar=show_progressbar,
#     698     early_stop_fn=early_stop_fn,
#     699     trials_save_file=trials_save_file,
#     700 )
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\hyperopt\fmin.py:553, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     550 rval.catch_eval_exceptions = catch_eval_exceptions
#     552 # next line is where the fmin is actually executed
# --> 553 rval.exhaust()
#     555 if return_argmin:
#     556     if len(trials.trials) == 0:
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\hyperopt\fmin.py:356, in FMinIter.exhaust(self)
#     354 def exhaust(self):
#     355     n_done = len(self.trials)
# --> 356     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     357     self.trials.refresh()
#     358     return self
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\hyperopt\fmin.py:292, in FMinIter.run(self, N, block_until_done)
#     289     time.sleep(self.poll_interval_secs)
#     290 else:
#     291     # -- loop over trials and do the jobs directly
# --> 292     self.serial_evaluate()
#     294 self.trials.refresh()
#     295 if self.trials_save_file != "":
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\hyperopt\fmin.py:170, in FMinIter.serial_evaluate(self, N)
#     168 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     169 try:
# --> 170     result = self.domain.evaluate(spec, ctrl)
#     171 except Exception as e:
#     172     logger.error("job exception: %s" % str(e))
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\hyperopt\base.py:907, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     898 else:
#     899     # -- the "work" of evaluating `config` can be written
#     900     #    either into the pyll part (self.expr)
#     901     #    or the normal Python part (self.fn)
#     902     pyll_rval = pyll.rec_eval(
#     903         self.expr,
#     904         memo=memo,
#     905         print_node_on_error=self.rec_eval_print_node_on_error,
#     906     )
# --> 907     rval = self.fn(pyll_rval)
#     909 if isinstance(rval, (float, int, np.number)):
#     910     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[33], line 25, in objective_rf(space)
#      13 def objective_rf(space):
#      14     model = Pipeline(
#      15             steps=[
#      16                 ('preprocessing_angles', AngleTransformer(angles = ['winddirection', 'yaw'])),
#    (...)
#      23             ]
#      24         )
# ---> 25     score = cross_val_score(model,   X_tr_ts, y_tr_ts, cv=5, scoring='neg_mean_squared_error').mean()
#      26     # We aim to maximize r2 score, therefore we return it as a negative value
#      27     return {'loss': -score, 'status': STATUS_OK }
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\sklearn\model_selection\_validation.py:515, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     512 # To ensure multimetric format is not supported
#     513 scorer = check_scoring(estimator, scoring=scoring)
# --> 515 cv_results = cross_validate(
#     516     estimator=estimator,
#     517     X=X,
#     518     y=y,
#     519     groups=groups,
#     520     scoring={"score": scorer},
#     521     cv=cv,
#     522     n_jobs=n_jobs,
#     523     verbose=verbose,
#     524     fit_params=fit_params,
#     525     pre_dispatch=pre_dispatch,
#     526     error_score=error_score,
#     527 )
#     528 return cv_results["test_score"]
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\sklearn\model_selection\_validation.py:266, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     263 # We clone the estimator to make sure that all the folds are
#     264 # independent, and that it is pickle-able.
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 266 results = parallel(
#     267     delayed(_fit_and_score)(
#     268         clone(estimator),
#     269         X,
#     270         y,
#     271         scorers,
#     272         train,
#     273         test,
#     274         verbose,
#     275         None,
#     276         fit_params,
#     277         return_train_score=return_train_score,
#     278         return_times=True,
#     279         return_estimator=return_estimator,
#     280         error_score=error_score,
#     281     )
#     282     for train, test in cv.split(X, y, groups)
#     283 )
#     285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\sklearn\utils\parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\sklearn\model_selection\_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\sklearn\pipeline.py:405, in Pipeline.fit(self, X, y, **fit_params)
#     403     if self._final_estimator != "passthrough":
#     404         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 405         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     407 return self
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\sklearn\ensemble\_forest.py:473, in BaseForest.fit(self, X, y, sample_weight)
#     462 trees = [
#     463     self._make_estimator(append=False, random_state=random_state)
#     464     for i in range(n_more_estimators)
#     465 ]
#     467 # Parallel loop: we prefer the threading backend as the Cython code
#     468 # for fitting the trees is internally releasing the Python GIL
#     469 # making threading more efficient than multiprocessing in
#     470 # that case. However, for joblib 0.12+ we respect any
#     471 # parallel_backend contexts set at a higher level,
#     472 # since correctness does not rely on using threads.
# --> 473 trees = Parallel(
#     474     n_jobs=self.n_jobs,
#     475     verbose=self.verbose,
#     476     prefer="threads",
#     477 )(
#     478     delayed(_parallel_build_trees)(
#     479         t,
#     480         self.bootstrap,
#     481         X,
#     482         y,
#     483         sample_weight,
#     484         i,
#     485         len(trees),
#     486         verbose=self.verbose,
#     487         class_weight=self.class_weight,
#     488         n_samples_bootstrap=n_samples_bootstrap,
#     489     )
#     490     for i, t in enumerate(trees)
#     491 )
#     493 # Collect newly grown trees
#     494 self.estimators_.extend(trees)
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\sklearn\utils\parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\sklearn\ensemble\_forest.py:184, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     181     elif class_weight == "balanced_subsample":
#     182         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 184     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     185 else:
#     186     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\sklearn\tree\_classes.py:1247, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1218 def fit(self, X, y, sample_weight=None, check_input=True):
#    1219     """Build a decision tree regressor from the training set (X, y).
#    1220
#    1221     Parameters
#    (...)
#    1244         Fitted estimator.
#    1245     """
# -> 1247     super().fit(
#    1248         X,
#    1249         y,
#    1250         sample_weight=sample_weight,
#    1251         check_input=check_input,
#    1252     )
#    1253     return self
#
# File c:\Users\Max\anaconda3\envs\soiltwin\lib\site-packages\sklearn\tree\_classes.py:379, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     368 else:
#     369     builder = BestFirstTreeBuilder(
#     370         splitter,
#     371         min_samples_split,
#    (...)
#     376         self.min_impurity_decrease,
#     377     )
# --> 379 builder.build(self.tree_, X, y, sample_weight)
#     381 if self.n_outputs_ == 1 and is_classifier(self):
#     382     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
RF_optimizations[mode] = convert_dict(RF_optimizations)[mode]
regr_rf_optimized = \
                Pipeline(
                    steps=[
                        ('preprocessing_angles', AngleTransformer(angles = ['winddirection', 'yaw'])),
                        ('regressor', RandomForestRegressor(
                            n_estimators = RF_optimizations[mode]['n_estimators'],
                            max_depth = RF_optimizations[mode]['max_depth'],
                            min_samples_split = RF_optimizations[mode]['min_samples_split']
                            )
                        )
                    ]
                )

regr_rf_optimized.fit(X_tr_ts, y_tr_ts)

regr_rf_optimized_pred = regr_rf_optimized.predict(X_test_ts)
regr_rf_optimized_mse = mean_squared_error(y_test_ts, regr_rf_optimized_pred)
regr_rf_optimized_r2 = r2_score(y_test_ts, regr_rf_optimized_pred)
print("RandomForestRegressor Optimized MSE:", regr_rf_optimized_mse, "RandomForestRegressor Optimized R2:", regr_rf_optimized_r2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 RF_optimizations[mode] = convert_dict(RF_optimizations)[mode]
#       2 regr_rf_optimized = \
#       3                 Pipeline(
#       4                     steps=[
#    (...)
#      12                     ]
#      13                 )
#      15 regr_rf_optimized.fit(X_tr_ts, y_tr_ts)
#
# KeyError: 'SS1'

# %%
from sklearn.metrics import mean_squared_error, r2_score
import keras_tuner
from tensorflow import keras
from keras import layers
from sklearn.preprocessing import StandardScaler

def build_model(hp):
    model = keras.Sequential()
    model.add(layers.Flatten())
        
    for i in range(num_hidden_layers):
        # Define the number of neurons for each hidden layer
        model.add(layers.Dense(
            units=hp.Int(f"units_{i}", min_value=8, max_value=128, step=8),
            activation="relu",
        ))
    
    model.add(layers.Dense(1, activation="linear"))
    model.compile(
        optimizer="adam", loss="mean_squared_error", metrics=["mean_squared_error"],
    )
    return model

tuners = {}
for num_hidden_layers in range(1, 4):
    print(f"Number of hidden layers: {num_hidden_layers}")
    tuners[num_hidden_layers] = keras_tuner.BayesianOptimization(
        hypermodel=build_model,
        objective="mean_squared_error",
        max_trials=10,
        executions_per_trial=1,
        overwrite=True,
        directory="my_dir",
        project_name="nn_multiple_hidden_layers",
    )
    tuners[num_hidden_layers].search_space_summary()

    tuners[num_hidden_layers].search(X_tr_ts_prep, y_tr_ts, epochs=50, validation_data=(X_test_ts_prep, y_test_ts))
    best_nn = tuners[num_hidden_layers].get_best_models()[0]
    best_nn.build(input_shape=(1, X_tr_ts_prep.shape[1]))
    best_nn.fit(X_tr_ts_prep, y_tr_ts, epochs=100, validation_data=(X_test_ts_prep, y_test_ts))

    best_nn_pred = best_nn.predict(X_test_ts_prep)
    best_nn_mse = mean_squared_error(y_test_ts, best_nn_pred)
    best_nn_r2 = r2_score(y_test_ts, best_nn_pred)
    print("NN Optimized MSE:", best_nn_mse, "NN Optimized R2:", best_nn_r2)
# Out:
# Number of hidden layers: 1
# Search space summary
# Default search space size: 1
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 128, 'step': 8, 'sampling': None}
#
# Search: Running Trial #1
#
# Value             |Best Value So Far |Hyperparameter
# 128               |?                 |units_0
#
# Epoch 1/50
# 12011/12011 [==============================] - 28s 2ms/step - loss: 3.1416e-04 - mean_squared_error: 3.1416e-04 - val_loss: 2.2953e-05 - val_mean_squared_error: 2.2953e-05
# Epoch 2/50
# 12011/12011 [==============================] - 31s 3ms/step - loss: 1.3730e-05 - mean_squared_error: 1.3730e-05 - val_loss: 8.0859e-06 - val_mean_squared_error: 8.0859e-06
# Epoch 3/50
# 11979/12011 [============================>.] - ETA: 0s - loss: 8.1237e-06 - mean_squared_error: 8.1237e-06
